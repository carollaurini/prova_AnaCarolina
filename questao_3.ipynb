# %%
import pandas as pd
import requests
import math

colDict = {} #dicionário para armazenar dados de coleções
install = "https://museudoouro.acervos.museus.gov.br/" #link do museu
col_endpoint  = install+"/wp-json/tainacan/v2/collections/" #endpoint da API para listar as coleções do acervo
col_r  =  requests.get(col_endpoint).json() #resultado da consulta das coleções do acervo

for collection in col_r:  #Cria um dicionário com os dados das coleções encontradas
    colDict[collection['name']] = {'id':collection['id'], 'total_items':collection['total_items']['publish']}

# %%
print(colDict)
# Out:
# {'Acervo Museológico': {'id': 3583, 'total_items': '101'}}

# %%
rows = []
for collectionName in colDict.keys():#itera para cada coleção encontrada
    total_pages = int(colDict[collectionName]['total_items'])/25 ##calcula o total de páginas de resultados
    print("Coletado dados para a coleção {}".format(collectionName))
    for page in range(int(math.ceil(total_pages))): #itera pelas páginas de resultados   
        page +=1 #pula a primeira página, a página 0 e 1 são iguais
        items_endpoint = install+"/wp-json/tainacan/v2/collection/{}/items/?perpage=25&paged={}".format(colDict[collectionName]['id'], page) #consulta à API
        item_r = requests.get(items_endpoint).json() #resultado da consulta em JSON
        if item_r["items"] == []:#se não houver mais dados para o script
            print("   * Todos os itens da coleção {} coletados".format(collectionName))
            break
        elif type(item_r) == dict:#se houver dados para coletar
            for item in item_r["items"]:#para cada item
                print("Coletando o item {}".format(item['id']))
                for metadata in item['metadata'].keys():#coleta os metadados e seus respectivos valores
                    metadado = item['metadata'][metadata]['name']#armazena o metadado
                    valor = item['metadata'][metadata]['value_as_string']#armazena os valores do metadado
                    if valor == "": #desconsidera valores nulos
                        continue
                    else: #Salve os valores das variáveis “metadado” em colunas e “valor” em linhas em um CSV.
                        rows.append([metadado,valor])
# Out:
# Coletado dados para a coleção Acervo Museológico
# Coletando o item 6505
# Número de registro
#
# 729
# Denominação
#
# Relicário
# Título
#
# Braço relicário
# Outros números
#
# MO 629 | Tombo nº 1950.02.37
# Classificação
#
# 09 Objetos Cerimoniais > 09.3 Objeto de Culto
# Local de produção
#
# Brasil | Minas Gerais
# Data de produção
#
# Século XVIII
# Procedência
#
# Ouro Preto - Minas Gerais
# Autor
#
# Não identificado
# Conjunto com nº
#
# 629
# Material/Técnica
#
# dourada | madeira esculpida | policromada
# Palavras-chave
#
# brasil | escultura | minas gerais | religião | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Dimensões
#
# Altura (cm): 38,0 Largura (cm): 10,2 Comprimento (cm): Profundidade (cm): 9,2 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Relicário na forma de um braço erguido, com a mão (direita) aberta, mas com o dedo mínimo dobrado na ponta; vestido por uma manga comprida, com pregas grossas; padronagem em acantos e esgrafitado dourado; com uma dobra verde na ponta; centro com um nicho elíptico, de fundo vermelho, com a boca delimitada por um entalhe em quatro volutas e frisos curvos; Base quadrangular, moldurada e frisada, dourada com a parte inferior em vermelho.
# Características técnicas
#
# Objeto esculpido em um só bloco de madeira, dourada e policromada em vermelho, verde e bege (na carnação da mão).
# Características estilísticas
#
# Objeto de provável origem mineira, de boa fatura, datável do século XVIII, com decoração e policromia ao gosto do barroco da 1ª metade.
# Características iconográficas/ornamentais
#
# Relicário em forma de uma mão.
# Dados históricos
#
# RELICÁRIO é uma urna ou cofre destinado a guarda de relíquias. RELÍQUIA é tudo aquilo que constitui o corpo físico de um santo (ossos, cabelos, dentes, etc.) ou algo que tenha entrado em contato com ele (partes de suas roupas, pertences pessoais, poeira de seu túmulo, etc). No século IV, estabeleceu-se que seria necessária a presença de uma relíquia para a sagração de uma igreja. Desse modo, pode-se dizer que o culto às relíquias foi o responsável direto pelo surgimento do culto às imagens de santos. Tal fato estimulou a multiplicação das relíquias, e mais do que isto, do comércio em torno delas. Isto implicou em muitas falsificações e criações fantasiosas. Durante a Idade Média, cabeças de São João Batista surgiram às dezenas; a crista do galo que cantou na negação de Pedro, às centenas; ossos dos santos, aos milhares. No entanto, o mais espetacular caso de relíquias, refere-se aos instrumentos de martírio de Jesus Cristo – as armas Christi, como são conhecidas. Consta que São Luís Rei de França, durante a sétima cruzada (séc. XIII), havia comprado em Constantinopla alguns desses instrumentos, como os cravos e a coroa de espinhos, e os levado para o Ocidente. Mas, misteriosamente, tais relíquias reapareceram na antiga capital do Império Bizantino algum tempo depois.
# Referências bibliográficas/arquivísticas
#
# Ficha de Inventário de 24-11-1989; Ficha de Conservação e Restauração de 23-11-1990; Ficha Topográfica 1997. FREEDBERG, David. El poder de las imágenes. Madrid, Cátedra, 1992, p. 119. DAMASCENO, Sueli. Glossário de bens imóveis (Igrejas de Ouro Preto). Ouro Preto, Instituto de Artes e Cultura/UFOP, 1987.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6483
# Número de registro
#
# 718
# Denominação
#
# Porcelana
# Título
#
# Jarro para barbear
# Outros números
#
# MO 392 | Tombo nº 1950.15.02
# Classificação
#
# 12 Objetos Pessoais > 12.3 Artigo de Toalete
# Local de produção
#
# China
# Data de produção
#
# Século XVIII
# Procedência
#
# São Paulo
# Autor
#
# Não identificado
# Conjunto com nº
#
# 392
# Material/Técnica
#
# cerâmica policromada | dourada
# Palavras-chave
#
# artigo de toalete | brasil | minas gerais | oriente | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Dimensões
#
# Altura (cm): 21,0 Largura (cm): Comprimento (cm): Profundidade (cm): Diâmetro (cm): 12,0 Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Jarro de pé circular, com dois frisos ocres; bojo com a parte inferior mais cheia e a superior cilíndrica, com decoração em flores alaranjadas e beges, com detalhes dourados, botões de flores cinzas e ramos com folhas verdes, cinzas e beges; borda circundada por duplo friso, com pequeno bico; alça auriforme, decorada por flor e elementos sinuosos, em tons laranja; com folhagens junto a sua base.
# Características técnicas
#
# Cerâmica em porcelana policromada nos tons vermelho, laranja, ocre, bege, cinza, verde e dourado.
# Características estilísticas
#
# Jarro que compõe conjunto de barbear, em Porcelana da Companhia das Índias, datável do século XVIII, de origem chinesa, decorada em motivos florais, colorida e policromada.
# Características iconográficas/ornamentais
#
# Flores, ramos com folhas picotadas, botões de flores, frisos.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 26-03-1975; Ficha de Conservação e Restauração de 19-10-1990; Ficha Topográfica 1991-1997; 2 fotos P&B. MOUTINHO, Stella Rodrigo Octavio et alii. Dicionário de Artes Decorativas e Decoração de Interiores. Rio de Janeiro. Ed. Nova Fronteira, 1999.
# Observações
#
# Conjunto adquirido em São Paulo
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6447
# Número de registro
#
# 699
# Denominação
#
# Escultura Religiosa
# Título
#
# Menino Jesus
# Outros números
#
# MO 699 | Tombo nº 1975.02.59
# Classificação
#
# 02 Artes Visuais/Cinematográfica > 02.3 Escultura
# Local de produção
#
# Brasil | Minas Gerais
# Data de produção
#
# Século XVIII
# Procedência
#
# Não identificada
# Autor
#
# Não identificado
# Material/Técnica
#
# dourada | madeira esculpida | policromada
# Palavras-chave
#
# escola mineira | escultura | religião | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Dimensões
#
# Altura (cm): 28,0 Largura (cm): 11,0 Comprimento (cm): Profundidade (cm): 11,0 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Figura esculpida do Menino Deus, de pé, nu, em posição frontal, de cabeça erguida, com os olhos à frente; cabelos dourados; braço esquerdo flexionado lateralmente, com a mão de segurar; braço direito flexionado à frente, com a mão de abençoar; perna esquerda flexionada e a outra reta; pés em ângulo;
# Características técnicas
#
# Menino Deus esculpido em uma só parte de madeira, pregado na base, policromado em bege, vermelho, azul e dourado nos cabelos.
# Características estilísticas
#
# Escultura de tratamento razoável, com a anatomia adiposa, rosto cheio, a boca com os lábios em recortes de bico e os membros roliços. De origem mineira, datável do século XVIII.
# Características iconográficas/ornamentais
#
# As representações em separado do Menino Jesus (não no colo da Virgem Maria, como é usual) são apreciadas a partir da Idade Média. Nelas, ele brinca com um pássaro ou segura um cacho de uvas. As representações do Menino acompanhado do globo terrestre (o Menino Deus, como são denominadas), já antes usual, só ganha grande popularidade no século XVI, difundidas especialmente na Itália e na Espanha. Nelas, o Menino aparece geralmente nu, de pé, tendo a mão direita de abençoar e a outra levando o globo terrestre.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha de Inventário de 13-08-1989; Ficha de Conservação e Restauração de 23-11-1990; Ficha Topográfica de 1991 a 1994. HENZ-MOHR, Gerd. Dicionário dos símbolos. São Paulo, Paulus, 1994.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6409
# Número de registro
#
# 679
# Denominação
#
# Tamborete sanitário
# Outros números
#
# MO 679 | sem nº tombo
# Classificação
#
# 05 Interiores > 05.5 Peça de Mobiliário
# Local de produção
#
# Brasil | Minas Gerais
# Data de produção
#
# Século XVIII
# Procedência
#
# Desconhecida
# Autor
#
# Não identificado
# Material/Técnica
#
# couro | madeira recortada
# Palavras-chave
#
# brasil | minas gerais | mobiliário | século xviii | usos e costumes
# Fotógrafo
#
# Daniel Mansur
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Tipo de tombamento
#
# Tombamento em conjunto
# Dimensões
#
# Altura (cm): 48,0 Largura (cm): 36,0 Comprimento (cm): Profundidade (cm):36,0 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Tamborete de assento quadrado, revestido por couro, com uma abertura circular ao meio; pernas de secção quandragular e lisas, afinadas inferiormente; amarração em travessas retas.
# Características técnicas
#
# Móvel em madeira, composto de 12 partes de madeira recortada, encaixadas e coladas; assento revestido de couro, que era fixado originalmente por tachas metálicas, com um recorte circular ao meio.
# Características estilísticas
#
# Tamborete para uso sanitário, característico do período colonial, de confecção rústica, com assento em couro cru.
# Características iconográficas/ornamentais
#
# Todo liso
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha de Inventário de 01-09-1990; Ficha de Conservação e Restauração de 20-04-1990; Ficha Topográfica 1991-1996
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6397
# Número de registro
#
# 672
# Denominação
#
# Maço de calceteiro
# Outros números
#
# MO 672 | Tombo nº 1950.31.58
# Classificação
#
# 06 Trabalho > 06.8 Equipamento de Uso Geral
# Local de produção
#
# Brasil | Minas Gerais
# Data de produção
#
# Século XIX | Século XVIII
# Procedência
#
# Região de Sabará
# Autor
#
# Não identificado
# Material/Técnica
#
# madeira recortada
# Palavras-chave
#
# equipamento de uso geral | minas gerais | século xix | século xviii
# Fotógrafo
#
# Daniel Mansur
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Tipo de tombamento
#
# Tombamento em conjunto
# Dimensões
#
# Altura (cm): 79 Largura (cm): 30 Comprimento (cm): Profundidade (cm): 20 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Bloco trapezoidal, liso, de cuja superfície superior se eleva um cabo comprido, de secção cilíndrica.
# Características técnicas
#
# Peça em madeira recortada, composta de duas partes encaixadas.
# Características estilísticas
#
# Instrumento rústico, de origem local, datável do século XVIII ou XIX, utilizado para socar pedras na construção de ruas.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha de Inventário de 04-01-1990; Ficha de Conservação e Restauração de 23-11-1990; Ficha Topográfica 1991-1996.
# Observações
#
# O mesmo que malho
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6389
# Número de registro
#
# 667
# Denominação
#
# Picúa
# Outros números
#
# MO 667 sem nº tombo
# Classificação
#
# 06 Trabalho > 06.6 Equipamento de Mineração
# Local de produção
#
# Brasil | Minas Gerais
# Data de produção
#
# Século XVIII
# Procedência
#
# [Diamantina]
# Autor
#
# Não identificado
# Material/Técnica
#
# madeira recortada
# Palavras-chave
#
# brasil | minas gerais | mineração | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Dimensões
#
# Altura (cm): 12,0 Largura (cm): Comprimento (cm): Profundidade (cm): Diâmetro (cm): 13,0 Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Recipiente em formato de canudo liso, com tampa semi-esférica, de encaixar.
# Características técnicas
#
# Peça em madeira recortada, em duas partes, com tampa de encaixe.
# Características estilísticas
#
# Recipiente para guarda de diamantes ou ouro, denominado de picuá, em madeira, simples; datável do século XVIII ou XIX e originário da região de Diamantina.
# Características iconográficas/ornamentais
#
# Sem ornamentos
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha de Inventário de 06-06-1990; Ficha de Conservação e Restauração de 22-11-1990; Ficha Topográfica 1991-1996.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6341
# Número de registro
#
# 641
# Denominação
#
# Escultura Religiosa
# Título
#
# Santa Catarina de Siena
# Outros números
#
# MO 641 | Tombo nº 1950.02.10
# Classificação
#
# 02 Artes Visuais/Cinematográfica > 02.3 Escultura
# Local de produção
#
# Brasil | Minas Gerais
# Data de produção
#
# Século XVIII
# Procedência
#
# [Igreja de Sabará]
# Autor
#
# Não identificado
# Conjunto com nº
#
# 427
# Material/Técnica
#
# dourada | madeira esculpida | policromada
# Palavras-chave
#
# escola mineira | escultura | religião | século xviii
# Fotógrafo
#
# Daniel Mansur
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Tipo de tombamento
#
# Tombamento em conjunto
# Dimensões
#
# Altura (cm): 47,0 Largura (cm): 23,5 Comprimento (cm): Profundidade (cm): 18,5 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Figura feminina, meia-idade, de pé, em posição frontal; cabeça inclinada à direita, olhos abaixados; braços flexionados a frente, sem as mãos; perna direita flexionada e a esquerda reta; pés em ângulo; Vestida com hábito e escapulário brancos, padronagem em motivos fitomorfos e florais dourados, com punções; cobrindo a cabeça uma coifa branca, de mesma padronagem, e véu preto; capa preta, que envolve a parte inferior do corpo, com padronagem em acantos e esgrafitos dourados; calça sapatos pretos com confetes dourados. Base elíptica vermelha, com quatro bicos, friso meia-cana invertida ao meio e friso dourado na borda superior.
# Características técnicas
#
# Imagem esculpida em um só bloco de madeira, dourada e policromada em vermelho, preto, branco e bege; punções e esgrafitos; furo na cabeça para resplendor.
# Características estilísticas
#
# Imagem de provável origem mineira, datável de meados do século XVIII, de boa fatura, com a composição bem proporcional, movimento contido, com panejamento em dobras de caimento reto; rosto inexpressivo, de olhos pintados, nariz fino, boca de lábios apertados e pouco recortados; o estofamento, bem elaborado, em acantos e folhagens grandes imitando adamascado, é ao gosto do barroco.
# Características iconográficas/ornamentais
#
# Imagem designada como Santa Catarina de Siena, santa dominicana que viveu no século XV (morreu em 1380, com 33 anos). Como atributos mais freqüentes pode ter uma coroa de espinhos ou rosas – a santa foi uma estigmatizada como São Francisco de Assis –, um crucifixo, um coração, um rosário na mão ou no cinto do hábito ou ainda um livro (a santa deixou vários escritos de cunho teológico, apesar de não saber ler e escrever). É comum vermos a santa ao lado de São Domingos na cena em que este recebe de Nossa Senhora o Rosário* (*)Como em uma bandeira pintada pertencente ao acervo do Museu.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 27-11-1989; Ficha de Conservação e Restauração 11-09-1990; Ficha Topográfica 1991-1996. CERINOTTI, Angela. Santos e Beatos de ontem e hoje. São Paulo, Globo, 2004 ROIG, Juan Ferrando. Iconografía de los Santos. Barcelona, Ediciones Omega, 1950.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6319
# Número de registro
#
# 630
# Denominação
#
# Escultura Religiosa
# Título
#
# Santa Cecília
# Classificação
#
# 02 Artes Visuais/Cinematográfica > 02.3 Escultura
# Local de produção
#
# Brasil | Minas Gerais
# Data de produção
#
# Século XIX
# Procedência
#
# Minas Gerais
# Modo de aquisição
#
# Doação
# Autor
#
# Não identificado
# Material/Técnica
#
# madeira esculpida | policromada
# Palavras-chave
#
# escola mineira | escultura | religião | século xix
# Fotógrafo
#
# Arquivo Museu do Ouro
# Data da fotografia
#
# 2020
# Esfera de proteção legal
#
# Federal
# Dimensões
#
# Altura (cm): 46,0 Largura (cm): 32,0 Comprimento (cm): Profundidade (cm): 18,0 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Imagem de roca desmontada, de uma figura feminina, composta do busto e de dois braços. Busto semi-esculpido, carnado de rosa, com os seios delineados; quatro recortes inferiores para fixação das ripas que formam o corpo da figura, e laterais dos ombros com pinos para fixação dos braços. Braços em duas partes unidas por articulação de bolacha nos cotovelos; parte posterior só desbastada; parte anterior (antebraço) carnada de rosa, terminado nas mãos, ambas tendo o anular e o médio dobrados, e os outros estendidos; na mão esquerda falta o dedo mínimo.
# Características técnicas
#
# Imagem de roca (ou de vestir) esculpida em madeira, composta de seis partes encaixadas; policromia em rosa pálido (carnação); marrom (cabelos e olhos) e vermelho (lábios).
# Características estilísticas
#
# Escultura de boa qualidade técnica, datável do século XIX, de rosto arredondado, olhos elípticos, de interior raso; sobrancelhas pintadas; nariz com a linha da frente chanfrada e ponta levemente arredondada; lábios de recortes suaves; mãos de dedos longilíneos e arredondados.
# Características iconográficas/ornamentais
#
# Iconografia: Mártir romana de família nobre. Forçada a casar, conseguiu converter o noivo S. Valentino ao Cristianismo e a levar vida casta e cristã. Recusando-se a sacrificar aos deuses, foi supliciada e, depois de morrer, sepultada no cemitério de Calixto. É representada tocando um instrumento musical ou, em alguns casos, a ouvir um anjo que toca. O seu atributo pessoal é um instrumento musical – uma lira ou um órgão de tubos, como é comum vê-la em Minas Gerais. Uma marca de sangue em volta do pescoço alude à sua degolação.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha de Inventário de 24-11-1989; 2 Fichas de Conservação e Restauração de 24-11-1989; 2 Fichas Topográfica de 1991. 14 fotos coloridas 25x18. TAVARES, Jorge Campos. Dicionário de Santos. Porto, Lello & Irmãos Editores, 1990.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6317
# Número de registro
#
# 629
# Denominação
#
# Relicário
# Título
#
# Braço relicário
# Outros números
#
# MO 629 | Tombo nº 1950.02.37
# Classificação
#
# 09 Objetos Cerimoniais > 09.3 Objeto de Culto
# Local de produção
#
# Brasil | Minas Gerais
# Data de produção
#
# Século XVIII
# Procedência
#
# Ouro Preto - Minas Gerais
# Autor
#
# Não identificado
# Conjunto com nº
#
# 729
# Material/Técnica
#
# dourada | madeira esculpida | policromada
# Palavras-chave
#
# brasil | escultura | minas gerais | religião | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Dimensões
#
# Altura (cm): 39,0 Largura (cm): 11,0 Comprimento (cm): Profundidade (cm): 9,2 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Relicário na forma de um braço erguido, com a mão (esquerda) aberta, mas com o dedo mínimo dobrado na ponta; vestido por uma manga comprida, com pregas grossas; padronagem em acantos e esgrafitado dourado; com uma dobra verde na ponta; centro com um nicho elíptico, de fundo vermelho, com a boca delimitada por um entalhe em quatro volutas e frisos curvos; Base quadrangular, moldurada e frisada, dourada com a parte inferior em vermelho.
# Características técnicas
#
# Objeto esculpido em um só bloco de madeira, dourada e policromada em vermelho, verde e bege (na carnação da mão).
# Características estilísticas
#
# Objeto de provável origem mineira, de boa fatura, datável do século XVIII, com decoração e policromia ao gosto do barroco da 1ª metade.
# Características iconográficas/ornamentais
#
# Relicário em forma de uma mão. RELICÁRIO é uma urna ou cofre destinado a guarda de relíquias. RELÍQUIA é tudo aquilo que constitui o corpo físico de um santo (ossos, cabelos, dentes, etc.) ou algo que tenha entrado em contato com ele (partes de suas roupas, pertences pessoais, poeira de seu túmulo, etc). No século IV, estabeleceu-se que seria necessária a presença de uma relíquia para a sagração de uma igreja. Desse modo, pode-se dizer que o culto às relíquias foi o responsável direto pelo surgimento do culto às imagens de santos. Tal fato estimulou a multiplicação das relíquias, e mais do que isto, do comércio em torno delas. Isto implicou em muitas falsificações e criações fantasiosas. Durante a Idade Média, cabeças de São João Batista surgiram às dezenas; a crista do galo que cantou na negação de Pedro, às centenas; ossos dos santos, aos milhares. No entanto, o mais espetacular caso de relíquias, refere-se aos instrumentos de martírio de Jesus Cristo – as armas Christi, como são conhecidas. Consta que São Luís Rei de França, durante a sétima cruzada (séc. XIII), havia comprado em Constantinopla alguns desses instrumentos, como os cravos e a coroa de espinhos, e os levado para o Ocidente. Mas, misteriosamente, tais relíquias reapareceram na antiga capital do Império Bizantino algum tempo depois.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha de Inventário de 24-11-1989; Ficha de Conservação e Restauração de 21-11-1990; Ficha Topográfica de 1997. FREEDBERG, David. El poder de las imágenes. Madrid, Cátedra, 1992, p. 119. DAMASCENO, Sueli. Glossário de bens imóveis (Igrejas de Ouro Preto). Ouro Preto, Instituto de Artes e Cultura/UFOP, 1987.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6289
# Número de registro
#
# 615
# Denominação
#
# Flauta e estojo
# Outros números
#
# MO 615 |  sem nº tombo
# Classificação
#
# 06 Trabalho > 06.10 Equipamento Musical
# Local de produção
#
# [Brasil]
# Data de produção
#
# Século XIX
# Procedência
#
# Sabará
# Modo de aquisição
#
# Compra
# Data de aquisição
#
# 1982
# Autor
#
# Não identificado
# Material/Técnica
#
# fundição | madeira | metal | recorte | torneado
# Palavras-chave
#
# brasil | instrumento musical | século xix
# Fotógrafo
#
# Acervo Museu do Ouro
# Data da fotografia
#
# 2020
# Esfera de proteção legal
#
# Federal
# Dimensões
#
# Altura (cm): Largura (cm): Comprimento (cm): 63,0 Profundidade (cm): Diâmetro (cm): 3,0 Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Flauta em ébano, de secção cilíndrica, dividida em três partes, com onze (11) registros e cinco (chaves) em metal prateado; a separação das partes é feita por aros em metal prateado. Estojo retangular, envernizado, com dois fechos de pressão e alça retangular ligeiramente curva; interior revestido por espuma e feltro azul, com dois suportes recortados em semicírculos, onde se encaixam as partes desmontadas da flauta.
# Características técnicas
#
# Flauta em ébano, torneado, desmontável em 5 partes; chaves* e aros em metal prateado (ou prata?), parafusados; estojo em madeira recortada, composta de 10 partes encaixadas e coladas; revestimento em feltro azul e espuma; falta a embocadura **.
# Características estilísticas
#
# Flauta datável do século XIX, de fabricação seriada.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha de Inventário de 23-11-1989/ 2 Fichas de Conservação e Restauração de 20-11-1990/ 4 Fichas Topográfica 1991 a 1993;
# Observações
#
# (*) A chave é a peça que serve para fechar ou abrir os orifícios; compõe-se de concha, haste e espátula. (**) A embocadura á parte superior dos instrumentos de sopro que se introduz na boca Comprada em 30/09/1982, de Benjamim Couto Lima e Luiz Pereira Lamego, de Sabará.Participou da exposição SESC/PMS – 1993, na Casa de Borba Gato. Medidas do estojo: 5,0 x 12,5 x 28,7 cm
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6271
# Número de registro
#
# 606
# Denominação
#
# Tesoura de ourives
# Outros números
#
# MO 606 | sem nº tombo
# Classificação
#
# 06 Trabalho > 06.3 Equipamento de Artistas/Artesãos
# Local de produção
#
# Brasil
# Data de produção
#
# Século XIX | Século XVIII
# Procedência
#
# Desconhecida
# Autor
#
# Não identificado
# Material/Técnica
#
# ferro fundido
# Palavras-chave
#
# brasil | minas gerais | ourivesaria | século xix | século xviii
# Fotógrafo
#
# Daniel Mansur
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Tipo de tombamento
#
# Tombamento em conjunto
# Dimensões
#
# Altura (cm): Largura (cm): 5,0 Comprimento (cm): 16,5 Profundidade (cm): 1,5 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Tesoura com duas hastes de extremos recurvados para dentro, retorcidas no outro extremo, onde se cruzam, formando a parte cortante, terminada em bico.
# Características técnicas
#
# Peça composta por duas partes de ferro fundido, unidas por pino.
# Características estilísticas
#
# Objeto datável do século XVIII ou XIX, de fatura rústica.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha de Inventário de 23-11-1989; Ficha de Conservação e Restauração de 20-11-1990; Ficha Topográfica 1991.
# Observações
#
# Tesoura ou alicate de ourives
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6133
# Número de registro
#
# 534
# Denominação
#
# Caixa de Santos Óleos
# Outros números
#
# MO 534 | Tombo nº 1975.13.24
# Classificação
#
# 09 Objetos Cerimoniais > 09.3 Objeto de Culto
# Local de produção
#
# [Minas Gerais]
# Data de produção
#
# Século XVIII
# Procedência
#
# Esmeralda
# Autor
#
# Não identificado
# Material/Técnica
#
# prata lavrada
# Palavras-chave
#
# brasil | minas gerais | ourivesaria | religião | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Marcas/Inscrições
#
# “P” e “C”
# Dimensões
#
# Altura (cm):11,0 Largura (cm):5,0 Comprimento (cm):11,5 Profundidade (cm): Diâmetro (cm): Peso (g): 365,0 Circunferência (cm):
# Resumo descritivo
#
# Caixa elíptica, com centro gravado em motivos fitomorfos com flores; borda frisada; tampa abaulada, gravada em motivos fitomorfos, com flores-de-lis e cartela oval de interior liso; com pequena pega torneada ao alto. Interior com um tampo superior, dividido em três compartimentos circulares, onde se encaixam dois frascos dos santos óleos. Ambos de formato cilíndrico, com friso inferior, terminado em um gargalo duplamente frisado, com tampa de borda estriada; marcados, um, com inscrição superior “P” e o outro, com “C”.
# Características técnicas
#
# Prata martelada, repuxada e gravada; dobradiça na tampa; pega fundida e soldada; frascos encaixados.
# Características estilísticas
#
# Peça em prata, datável do século XVIII, com decoração barroca, em acantos e flores; não apresenta marcas, o que faz supor se tratar de uma peça mineira.
# Características iconográficas/ornamentais
#
# Acantos, flores, torneados, cartela e frisos.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto. Caixa para os santos óleos é o recipiente usado para guardar os três distintos óleos do Batismo, do Crisma e do Sacramento dos Enfermos. Em número de três, costumam trazer inscrições indicativas de cada conteúdo: OS – Oleum Sanctum ou Óleo dos Catecúmenos; SC – Sanctum Chrisma; e OI – Oleum Infirmorum. Nos frascos dessa caixa as inscrições “C” e “P”
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração 12-11-1990; Ficha Topográfica 1991-1997. DAMASCENO, Sueli. Glossário de Bens Móveis (igrejas mineiras). Ouro Preto, UFOP/Instituto de Artes e Cultura, 1987.
# Observações
#
# Medidas complementares: Frasco “P” = 7,2 x Ø = 3 x 40 gr; Frasco “C” = 7,2 x Ø = 3 x 45 gr
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6131
# Número de registro
#
# 533
# Denominação
#
# Ostensório
# Outros números
#
# MO 533 | Tombo nº 1975.13.23
# Classificação
#
# 09 Objetos Cerimoniais > 09.3 Objeto de Culto
# Local de produção
#
# [Brasil]
# Data de produção
#
# Século XVIII
# Procedência
#
# Pernambuco
# Modo de aquisição
#
# Compra
# Autor
#
# Não identificado
# Material/Técnica
#
# ouro lavrado | prata | vidro
# Palavras-chave
#
# brasil | ourivesaria | pernambuco | religião | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Dimensões
#
# Altura (cm): 59,0 Largura (cm): 17,5 Comprimento (cm): Profundidade (cm): 16,2 Diâmetro (cm): 16,2 Peso (g): 3100,0 Circunferência (cm):
# Resumo descritivo
#
# Ostensório em prata dourada, com a base campanulada, em frisos salientes; coluna torneada em nós, frisos e estrangulamentos; copo de bojo semi-esférico, decorado em seis molduras salientes e gravações curvas; nele se encaixa o corpo da custódia, de base com extremidades recurvadas, faces decoradas com folhas de acantos e cartelas centrais com cabeças de anjos; nas quinas (4) colunas de socos em guilhochês, listel em caneluras e capitel de acantos; centro com a superfície gravada em círculo de acantos; visor circular liso, com um lado envidraçado; no interior uma luneta de ouro em crescente, com três cabeças de anjos; parte superior em cimalha retangular, com as frentes abauladas, revestidas em acantos e flores; arremate em cúpula semi-esférica, revestida por acantos em relevo, encimada por cruz latina, de traves torneadas com acantos; ladeando a cúpula, quatro pináculos torneados, que aparecem também na parte inferior da base.
# Características técnicas
#
# Peça em prata e ouro fundidos, martelados, repuxados e cinzelados, desmontável em 20 partes, atarraxadas; visor com porta envidraçada; prata banhada a ouro; copo, visor e luneta em ouro.
# Características estilísticas
#
# Ostensório de provável origem brasileira, já que não apresenta nenhuma marca, originária de Pernambuco, com a decoração ao gosto barroco, de acantos, cartelas, volutas, guilhochês e cabeças de anjos;
# Características iconográficas/ornamentais
#
# Frisos, nós, acantos, cartelas, volutas, colunas com guilhochês, caneluras e capitéis de acantos, flores, pináculos e molduras; cabeças de anjos e cruz latina; lua crescente.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração 12-11-1990; Ficha Topográfica 1991-1996; 1 Foto P&B nº 307.
# Observações
#
# Também denominado Custódia.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6129
# Número de registro
#
# 532
# Denominação
#
# Ostensório
# Outros números
#
# MO 532 | Tombo nº 1975.13.25
# Classificação
#
# 09 Objetos Cerimoniais > 09.3 Objeto de Culto
# Local de produção
#
# [Minas Gerais]
# Data de produção
#
# Século XVIII
# Procedência
#
# Santa Bárbara
# Autor
#
# Não identificado
# Material/Técnica
#
# prata lavrada
# Palavras-chave
#
# brasil | minas gerais | ourivesaria | religião | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Dimensões
#
# Altura (cm): 22,5 Largura (cm): 21,0 Comprimento (cm): Profundidade (cm): Diâmetro (cm): 9,5 Peso (g): 455,0 Circunferência (cm):
# Resumo descritivo
#
# Ostensório de base campanulada, com a borda frisada em volutas e ondulados seqüenciados; coluna curta, torneada; visor circular, com a frente envidraçada, circundado por rainonado de raios ondulados mesclados com raios retos, com contorno interno em friso cordão; está ladeado por duas cabeças de anjos e encimado por uma cruz torneada sobre esfera; tampa traseira decorada em motivos fitomorfos, com dobradiça e pequeno fecho; interior com local para encaixe da luneta.
# Características técnicas
#
# Peça em prata martelada, repuxada, fundida e cinzelada, desmontável em cinco partes; cruz, coluna e cabeça de anjos fundidas e soldadas; visor com vidro transparente, encaixado.
# Características estilísticas
#
# Ostensório em prata lavrada, com decoração barroca em volutas, cabeças de anjos, frisos e torneados, datável do século XVIII; não apresenta marcas do ourives e da contrastaria, o que faz supor se tratar de uma peça de origem mineira.
# Características iconográficas/ornamentais
#
# Raionado, cabeças de anjos, cruz latina, friso cordão, volutas, ondulados, torneados e motivos fitomorfos.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração 16-02-1990; Ficha Topográfica 1991; 1 Foto P&B nº 306
# Observações
#
# Também denominado de Custódia.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6127
# Número de registro
#
# 531
# Denominação
#
# Naveta
# Outros números
#
# MO 531 | Tombo nº 1950.13.22
# Classificação
#
# 09 Objetos Cerimoniais > 09.3 Objeto de Culto
# Local de produção
#
# [Minas Gerais]
# Data de produção
#
# Século XVIII
# Procedência
#
# Vale do Paraopeba
# Autor
#
# Não identificado
# Conjunto com nº
#
# 509
# Material/Técnica
#
# prata lavrada
# Palavras-chave
#
# brasil | minas gerais | ourivesaria | religião | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Dimensões
#
# Altura (cm): 14,0 Largura (cm): 7,5 Comprimento (cm): 17,0 Profundidade (cm): Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Naveta de base elíptica, frisada ao centro, seguida de curta coluna torneada em nós e friso; bojo pseudo cordiforme, circundado por frisos em cês e angras, com arremate de flores e folhagens; fundo puncionado; ao centro, nas duas faces, uma espécie de brasão composto por nuvens, com estrela central e duas outras por cima; superfície superior, com o centro rebaixado, com dobradiça; borda contornada por frisos, com arremate de acantos nas pontas; fundo puncionado em estrelas; uma das metades abre-se em forma de tampa.
# Características técnicas
#
# Peça em prata martelada, repuxada, fundida e cinzelada, composta de três partes; coluna fundida e soldada ao meio; tampa com dobradiça.
# Características estilísticas
#
# Naveta em prata lavrada, de boa execução, datável da segunda metade do século XVIII, com decoração típica da época, em transição do joanino para o rococó, com cês, angras, acantos, flores. Não apresenta marcas do ourives e da contrastaria, o que faz supor se tratar de uma peça mineira.
# Características iconográficas/ornamentais
#
# O brasão com as três estrelas e o monte pode ser o da Ordem Terceira do Carmo; cês, angras, flores, punções, folhagens.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração de 12-11-1990; Ficha Topográfica 1991-1997; 1 Foto P&B nº 305.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6125
# Número de registro
#
# 530
# Denominação
#
# Naveta
# Outros números
#
# MO 530 | Tombo nº 1950.13.22
# Classificação
#
# 09 Objetos Cerimoniais > 09.3 Objeto de Culto
# Local de produção
#
# [Rio de Janeiro]
# Data de produção
#
# Século XVIII
# Procedência
#
# Vale do Paraopeba
# Autor
#
# Não identificado
# Material/Técnica
#
# prata lavrada
# Palavras-chave
#
# brasil | minas gerais | ourivesaria | religião | século xviii
# Fotógrafo
#
# Daniel Mansur
# Esfera de proteção legal
#
# Federal
# Marcas/Inscrições
#
# Um “B” sobreposto a um “F” (?), um “R” coroado e a marca do toque, em zigue-zague
# Dimensões
#
# Altura (cm): 15 Largura (cm): 8 Comprimento (cm): 19 Profundidade (cm): Diâmetro (cm): 9 Peso (g): 510,0 Circunferência (cm):
# Resumo descritivo
#
# Naveta no formato de uma caravela, com a base circular, revestida por lingüetas; bojo com as laterais imitando emendas do madeirame do casco; proa, mas baixa, arredondada e frisada na frente, com pequena elevação circundante; popa alta, enrolada no extremo, onde aparece revestida por acantos, com desenho de janelas, portas e guilhochês; abre-se como uma tampa; toda borda contornada por friso de cordão; o meio do convés rebaixado em curva, com desenho imitando o madeirame e uma porta; decoração semelhante à da proa.
# Características técnicas
#
# Peça em prata martelada, repuxada, fundida e cinzelada, composta de três partes; base soldada ao bojo; tampa com dobradiça.
# Características estilísticas
#
# Naveta em prata lavrada, de boa execução, com desenho característico do setecentos, no formato de uma caravela, com decoração de acantos, lingüetas e guilhochês. Apresenta marcas do ourives e da contrastaria, sendo esta última identificada com o Rio de Janeiro.
# Características iconográficas/ornamentais
#
# Caravela portuguesa; friso cordão, acantos, lingüetas, guilhochês.
# Dados históricos
#
# Marcas não identificadas; a do ourives pode ser “FBA” ou “FB” sobrepostos; o da contrastaria é com certeza um “R” coroado, relativo a uma marca de contraste do Rio de Janeiro de fins do século XVIII ou início do XIX.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração de 12-11-1990; Ficha Topográfica 1991-1997; VIDAL, Manoel Gonçalves. Marcas de contrastes e ourives portugueses. Lisboa, Imprensa Nacional/Casa da Moeda, 1974, vol. 1.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6115
# Número de registro
#
# 525
# Denominação
#
# Comenda árabe
# Outros números
#
# MO 525 | Tombo nº 1952.22.01
# Classificação
#
# 09 Objetos Cerimoniais > 09.2 Objeto Comemorativo
# Local de produção
#
# França
# Data de produção
#
# Século XX
# Procedência
#
# Desconhecida
# Autor
#
# Não identificado
# Material/Técnica
#
# esmalte | ouro fundido | prata
# Palavras-chave
#
# frança | objeto comemorativo | século xx
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Marcas/Inscrições
#
# “Nº 46/ Kretly/ Palais-Royal/Paris” e inscrições em árabe.
# Dimensões
#
# Altura (cm): Largura (cm): Comprimento (cm): Profundidade (cm): 2,0 Diâmetro (cm): 10,0 Peso (g): 110,0 Circunferência (cm):
# Resumo descritivo
#
# Comenda em forma de uma estrela convexa, com cinco pontas mais destacadas, compostas por inúmeros filetes lanceolados, todos contornados por friso cordão e com relevo em ponta de diamante; ao centro um círculo de aro dourado por fora e um aro intermediário em vermelho com inscrições douradas em árabe; interior dourado, com monograma, também em árabe, dourado e em relevo; ao redor desse círculo sete luas crescentes com estrelas de cinco pontas, também delimitadas por friso cordão e com relevos em ponta de diamante. No verso, dois ganchos e marca de uma presilha maior; e ao meio uma inscrição em francês.
# Características técnicas
#
# Peça em metal branco (prata?), fundido e filigranado, com esmaltado vermelho e partes douradas; partes soldadas.
# Características estilísticas
#
# Comenda com inscrições em árabe, datável do século XX.
# Características iconográficas/ornamentais
#
# Luas crescentes, estrelas, pontas de diamante; friso cordão.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração 12-11-1990; Ficha Topográfica 1991. 4 fotos coloridas numeradas ( a lápis)12, 13 14 e 16.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6113
# Número de registro
#
# 524
# Denominação
#
# Comenda
# Título
#
# Ordem de Cristo
# Outros números
#
# MO 524 | Tombo nº 1952.22.02
# Classificação
#
# 09 Objetos Cerimoniais > 09.2 Objeto Comemorativo
# Local de produção
#
# [Portugal]
# Data de produção
#
# [Século XVIII]
# Procedência
#
# Desconhecida
# Autor
#
# Não identificado
# Material/Técnica
#
# esmalte | fundição | martelagem | prata dourada
# Palavras-chave
#
# objeto comemorativo | portugal | século xviii
# Fotógrafo
#
# Daniel Mansur
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Tipo de tombamento
#
# Tombamento em conjunto
# Dimensões
#
# Altura (cm): 9,0 Largura (cm): 4,5 Comprimento (cm): Profundidade (cm): 0,7 Diâmetro (cm): Peso (g): 50,0 Circunferência (cm):
# Resumo descritivo
#
# Comenda em formato de cruz dourada, com a frente esmaltada em vermelho, com a borda em friso rendilhado; centro com outra cruz, em esmaltado branco, com contorno em friso dourado; parte superior com alça formada por dois êsses e um cê invertido, onde se prende uma argola elíptica chapeada, com a frente ornada em relevo de ramos com flores miúdas.
# Características técnicas
#
# Cruz em prata martelada e fundida, banhada a ouro, com esmaltado branco e vermelho; alça martelada e cinzelada, encaixada.
# Características iconográficas/ornamentais
#
# Comenda da Ordem de Cristo
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração 12-11-1990; Ficha Topográfica 1991; 1 foto colorida.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6111
# Número de registro
#
# 523
# Denominação
#
# Comenda
# Título
#
# [Ordem dos Cavaleiros do Santo Sepulcro]
# Outros números
#
# MO 523 |  Tombo nº 1952.22.03
# Classificação
#
# 09 Objetos Cerimoniais > 09.2 Objeto Comemorativo
# Local de produção
#
# Europa
# Data de produção
#
# [Século XVIII]
# Procedência
#
# Desconhecida
# Autor
#
# Não identificado
# Material/Técnica
#
# esmalte | prata fundida
# Palavras-chave
#
# europa | objeto comemorativo | século xviii
# Fotógrafo
#
# Daniel Mansur
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Tipo de tombamento
#
# Tombamento em conjunto
# Dimensões
#
# Altura (cm): 9,5 Largura (cm): 4,0 Comprimento (cm): Profundidade (cm): 0,7 Diâmetro (cm): Peso (g): 40,0 Circunferência (cm):
# Resumo descritivo
#
# Comenda em cruz de travessões terminados em ponteiras perpendiculares; centro esmaltado em vermelho, com borda em friso serilhado (frente e verso); entre os ângulos, outras quatro cruzes menores, de mesmo feitio; arremate em uma coroa real, decorada com flores e friso perolado e encimada por globo com cruz latina, com argola circular onde se prende uma alça elíptica chapeada.
# Características técnicas
#
# Comenda em prata fundida e esmaltada em vermelho; coroa, argola e alça encaixadas.
# Características iconográficas/ornamentais
#
# Trata-se da Cruz de Jerusalém que simboliza as cinco chagas de Cristo, que é a sigla da Ordem dos Cavaleiros do Santo Sepulcro.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração 12-11-1990; Ficha Topográfica 1991; 2 fotos coloridas.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6085
# Número de registro
#
# 509
# Denominação
#
# Turíbulo
# Outros números
#
# MO 509 | Tombo nº 1948.13.20
# Classificação
#
# 09 Objetos Cerimoniais > 09.3 Objeto de Culto
# Local de produção
#
# [Minas Gerais]
# Data de produção
#
# Século XVIII
# Procedência
#
# Vale do Paraopeba
# Autor
#
# Não identificado
# Material/Técnica
#
# prata lavrada
# Palavras-chave
#
# minas gerais | ourivesaria | religião | século xviii
# Fotógrafo
#
# Daniel Mansur
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Tipo de tombamento
#
# Tombamento em conjunto
# Dimensões
#
# Altura (cm): 19,5/90,0 (total) Largura (cm): Comprimento (cm): Profundidade (cm): Diâmetro (cm): 11,5 Peso (g): 930,0 Circunferência (cm):
# Resumo descritivo
#
# Turíbulo de base circular, frisada; bojo abaulado, decorado em três cartelas, circundadas por angras, em cujo interior aparece um brasão encimado por coroa composto por nuvens com uma estrela central e duas outras por cima; envolvimento de acantos que descem da borda, onde aparece um ressalto curvo com orifício, onde se prende a corrente da tampa. Tampa em formato de cúpula, decorada em angras centrando vazados com folhas; envolvimento em folhas de acantos e junto à borda uma alça arrematada por palmeta (duas já substituídas) por onde corre a corrente; arremate m frisos e uma pinha revestida por folhagens. Quatro partes de correntes, presas superiormente a um prato circular, frisado, com orifício central, por onde corre uma das correntes, arrematada por argola.
# Características técnicas
#
# Peça em prata fundida e cinzelada, composta por oito partes; quatro partes de correntes de espinho; duas alças de cobre substituem as originais, em prata.
# Características estilísticas
#
# Naveta em prata lavrada, de boa execução, datável da segunda metade do século XVIII, com decoração típica da época, em transição do joanino para o rococó, com cês, angras, acantos, flores. Não apresenta marcas do ourives e da contrastaria, o que faz supor se tratar de uma peça mineira.
# Características iconográficas/ornamentais
#
# O brasão com as três estrelas e o monte pode ser o da Ordem Terceira do Carmo; cês, angras, flores, punções, folhagens.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha cadastral de 27-03-1975; Ficha de Conservação e Restauração 09-11-1990; Ficha Topográfica 1991-1996; 1 foto P&B no 299.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6083
# Número de registro
#
# 508
# Denominação
#
# Fivela
# Outros números
#
# MO 508 | Tombo nº 1975.33.04
# Classificação
#
# 12 Objetos Pessoais > 12.1 Acessório de Indumentária
# Local de produção
#
# [Brasil]
# Data de produção
#
# Século XVIII
# Procedência
#
# Desconhecida
# Autor
#
# Não identificado
# Material/Técnica
#
# lavrado | metal dourado
# Palavras-chave
#
# acessório de indumentária | brasil | minas gerais | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Dimensões
#
# Altura (cm): Largura (cm): 7,0 Comprimento (cm):10,5 Profundidade (cm):2,5 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Fivela dourada de formato oval, convexa, contornada por frisos tremidos, formando dois bicos, com vazados e palmetas nos cantos; interior com relevo de brasão coroado com as Armas da Coroa Portuguesa, acompanhado de cornetas e estandartes, com cercadura em rocalhas; Possui por trás duas hastes transversais, uma delas provida de dois pinos afiados.
# Características técnicas
#
# Fivela em metal (cobre ou bronze), fundido e cinzelado, com banho de ouro.
# Características estilísticas
#
# Fivela com decoração de gosto rococó, em palmetas e concheados, estampando as Armas da Coroa Portuguesa; certamente trata-se de uma peça do período colonial de uso particular.
# Características iconográficas/ornamentais
#
# Rocalhas, palmetas D. José e brasão coroado com as Armas da Coroa Portuguesa com os sete castelos e as cinco quinas, acompanhada por cornetas e estandartes.
# Dados históricos
#
# Não foram localizados dados específicos sobre o objeto.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 2-03-1975; Ficha de Conservação e Restauração de 22-10-1990; Ficha Topográfica 1991-1996.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 6081
# Número de registro
#
# 507
# Denominação
#
# Brasão
# Outros números
#
# MO 597 | Tombo nº 1975.13.18
# Classificação
#
# 08 Insígnias
# Local de produção
#
# [Minas Gerais]
# Data de produção
#
# Século XVIII
# Procedência
#
# Desconhecida
# Autor
#
# Não identificado
# Material/Técnica
#
# cobre lavrado | dourada
# Palavras-chave
#
# armas da coroa portuguesa | insígnia | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Dimensões
#
# Altura (cm):18,0 Largura (cm): 14,0 Comprimento (cm): Profundidade (cm): 0,5 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Brasão oval, todo dourado, com vazado, contornado por angras, volutas e êsses entrelaçado por ramos sinuosos; arremate inferior em palmeta e superior em coroa real; centro com relevo das Armas da Coroa Portuguesa.
# Características técnicas
#
# Brasão em cobre martelado e cinzelado, com banho de ouro na parte da frente.
# Características estilísticas
#
# ...
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 18-01-1975; Ficha de Conservação e Restauração de 19-03-1990; Ficha Topográfica 1991-1997. CANTI, Tilde. O móvel no Brasil. Origem, evolução e características. Rio de Janeiro, Editora Agir/Lisboa, Fundação Ricardo do Espírito Santo, 1999.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 5233
# Número de registro
#
# 64
# Denominação
#
# Cadeira de Sola
# Outros números
#
# MO 64 | Tombo nº 1941.03.01
# Classificação
#
# 05 Interiores > 05.5 Peça de Mobiliário
# Local de produção
#
# Brasil | Minas Gerais
# Data de produção
#
# Século XVIII
# Procedência
#
# Sabará - Casa de Câmara e Cadeia
# Autor
#
# Não identificado
# Material/Técnica
#
# couro lavrado | madeira | marcenaria | metal
# Palavras-chave
#
# brasil | minas gerais | mobiliário | século xix | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Tipo de tombamento
#
# Tombamento em conjunto
# Marcas/Inscrições
#
# “Vila Real de N. S. Da Conceição Do Sabará”
# Dimensões
#
# Altura (cm): 134,0 Largura (cm): 57,0 Comprimento (cm): Profundidade (cm): 58,0 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Cadeira de espaldar alto, reclinado, com recortes curvos superior e inferior; revestimento em couro decorado com o brasão das Armas de Portugal, com inscrição circundante, coroado e delimitado por frisos curvos, volutas, guirlandas de flores e acantos sinuosos, com dois putos inferiores a maneira de atlantes; contorno em friso de lingüeta, com palmeta superior; tacheado miúdo na frente e laterais; com arremate de pináculos nas quinas; assento de formato trapezoidal, mas de desenho curvo, revestido por couro, com decoração em volutas, acantos sinuosos, conchas e palmetas, guirlanda de flores e dois leões alados; contorno em friso de lingüeta, com a borda moldurada; pernas dianteiras com joelhos de saída, contornadas por frisos; pernas traseiras recurvadas e cilíndricas; amarração em “H” sinuoso, com travessas emolduradas; a traseira cilíndrica; pés cônicos, torneados.
# Características técnicas
#
# Cadeira em jacarandá, composta por cerca de 20 partes em madeira recortada e torneada, encaixadas e fixadas por cavilhas; assento e espaldar revestidos em couro lavrado; tacheado miúdo e pináculos em metal amarelo; assento de encaixe.
# Características estilísticas
#
# Cadeira dita de Sola, fazendo parte de conjunto que pertenceu à antiga Câmara e Cadeia da Vila de Sabará, no período colonial; de fatura esmerada, com desenho elegante, de espaldar alto, assento curvo, pernas com joelho e amarração em “H”, toda revestida em couro lavrado, com decoração esmerada, ao gosto barroco D. João V, com acantos, conchas, palmetas, Armas da Coroa portuguesa, figuras de atalntes e leões alados.
# Características iconográficas/ornamentais
#
# Armas da Coroa portuguesa, atlantes, leões alados e decoração típica do estilo D. João V, com acantos, conchas, palmetas, acantos sinuosos e lingüetas; tacheado miúdo e pináculos.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 18-01-1975; Ficha de Conservação e Restauração de 19-03-1990; Ficha Topográfica 1991-1997. CANTI, Tilde. O móvel no Brasil. Origem, evolução e características. Rio de Janeiro, Editora Agir/Lisboa, Fundação Ricardo do Espírito Santo, 1999.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 5231
# Número de registro
#
# 63
# Denominação
#
# Cadeira de Sola
# Outros números
#
# MO 63 | Tombo nº 1941.03.01
# Classificação
#
# 05 Interiores > 05.5 Peça de Mobiliário
# Local de produção
#
# Brasil | Minas Gerais
# Data de produção
#
# Século XVIII
# Procedência
#
# Sabará - Casa de Câmara e Cadeia
# Autor
#
# Não identificado
# Material/Técnica
#
# couro lavrado | madeira | marcenaria | metal
# Palavras-chave
#
# brasil | minas gerais | mobiliário | século xix | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Tipo de tombamento
#
# Tombamento em conjunto
# Marcas/Inscrições
#
# “Vila Real de N. S. Da Conceição Do Sabará”
# Dimensões
#
# Altura (cm): 134,0 Largura (cm): 57,0 Comprimento (cm): Profundidade (cm): 58,0 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Cadeira de espaldar alto, reclinado, com recortes curvos superior e inferior; revestimento em couro decorado com o brasão das Armas de Portugal, com inscrição circundante, coroado e delimitado por frisos curvos, volutas, guirlandas de flores e acantos sinuosos, com dois putos inferiores a maneira de atlantes; contorno em friso de lingüeta, com palmeta superior; tacheado graúdo na frente e laterais; com arremate de pináculos nas quinas; assento de formato trapezoidal, mas de desenho curvo, revestido por couro, com decoração em volutas, acantos sinuosos, conchas e palmetas, guirlanda de flores e dois leões alados; contorno em friso de lingüeta, com a borda moldurada; pernas dianteiras com joelhos de saída, contornadas por frisos; pernas traseiras recurvadas e cilíndricas; amarração em “H” sinuoso, com travessas emolduradas; a traseira cilíndrica; pés cônicos, torneados.
# Características técnicas
#
# Cadeira em jacarandá, composta por cerca de 20 partes em madeira recortada e torneada, encaixadas e fixadas por cavilhas; assento e espaldar revestidos em couro lavrado; tacheado graúdo e pináculos em metal amarelo; assento de encaixe.
# Características estilísticas
#
# Cadeira dita de Sola, fazendo parte de conjunto que pertenceu à antiga Câmara e Cadeia da Vila de Sabará, no período colonial; de fatura esmerada, com desenho elegante, de espaldar alto, assento curvo, pernas com joelho e amarração em “H”, toda revestida em couro lavrado, com decoração esmerada, ao gosto barroco D. João V, com acantos, conchas, palmetas, Armas da Coroa portuguêsa, figuras de atlantes e leões alados.
# Características iconográficas/ornamentais
#
# Armas da Coroa portuguesa, atlantes, leões alados e decoração típica do estilo D. João V, com acantos, conchas, palmetas, acantos sinuosos e lingüetas; tacheado graúdo e pináculos.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 18-01-1975; Ficha de Conservação e Restauração de 19-03-1990; Ficha Topográfica 1991-1997. CANTI, Tilde. O móvel no Brasil. Origem, evolução e características. Rio de Janeiro, Editora Agir/Lisboa, Fundação Ricardo do Espírito Santo, 1999.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 5229
# Número de registro
#
# 62
# Denominação
#
# Cadeira de Sola
# Outros números
#
# MO 62 | Tombo nº 1941.03.01
# Classificação
#
# 05 Interiores > 05.5 Peça de Mobiliário
# Local de produção
#
# Brasil | Minas Gerais
# Data de produção
#
# Século XVIII
# Procedência
#
# Sabará - Casa de Câmara e Cadeia
# Autor
#
# Não identificado
# Material/Técnica
#
# couro lavrado | madeira | marcenaria | metal
# Palavras-chave
#
# brasil | minas gerais | mobiliário | século xix | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Tipo de tombamento
#
# Tombamento em conjunto
# Marcas/Inscrições
#
# “Vila Real de N. S. Da Conceição Do Sabará”
# Dimensões
#
# Altura (cm): 134,0 Largura (cm): 57,0 Comprimento (cm): Profundidade (cm): 58,0 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Cadeira de espaldar alto, reclinado, com recortes curvos superior e inferior; revestimento em couro decorado com o brasão das Armas de Portugal, com inscrição circundante, coroado e delimitado por frisos curvos, volutas, guirlandas de flores e acantos sinuosos, com dois putos inferiores a maneira de atlantes; contorno em friso de lingüeta, com palmeta superior; tacheado miúdo na frente e laterais; com arremate de pináculos nas quinas; assento de formato trapezoidal, mas de desenho curvo, revestido por couro, com decoração em volutas, acantos sinuosos, conchas e palmetas, guirlanda de flores e dois leões alados; contorno em friso de lingüeta, com a borda moldurada; pernas dianteiras com joelhos de saída, contornadas por frisos; pernas traseiras recurvadas e cilíndricas; amarração em “H” sinuoso, com travessas emolduradas; a traseira cilíndrica; pés cônicos, torneados.
# Características técnicas
#
# Cadeira em jacarandá, composta por cerca de 20 partes em madeira recortada e torneada, encaixadas e fixadas por cavilhas; assento e espaldar revestidos em couro lavrado; tacheado miúdo e pináculos em metal amarelo; assento de encaixe.
# Características estilísticas
#
# Cadeira dita de Sola, fazendo parte de conjunto que pertenceu à antiga Câmara e Cadeia da Vila de Sabará, no período colonial; de fatura esmerada, com desenho elegante, de espaldar alto, assento curvo, pernas com joelho e amarração em “H”, toda revestida em couro lavrado, com decoração esmerada, ao gosto barroco D. João V, com acantos, conchas, palmetas, Armas da Coroa portuguesa, figuras de atlantes e leões alados.
# Características iconográficas/ornamentais
#
# Armas da Coroa portuguesa, atlantes, leões alados e decoração típica do estilo D. João V, com acantos, conchas, palmetas, acantos sinuosos e lingüetas; tacheado miúdo e pináculos.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 18-01-1975; Ficha de Conservação e Restauração de 19-03-1990; Ficha Topográfica 1991-1997. CANTI, Tilde. O móvel no Brasil. Origem, evolução e características. Rio de Janeiro, Editora Agir/Lisboa, Fundação Ricardo do Espírito Santo, 1999.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 5227
# Número de registro
#
# 61
# Denominação
#
# Cadeira de Sola
# Outros números
#
# MO 61 | Tombo nº 1941.03.01
# Classificação
#
# 05 Interiores > 05.5 Peça de Mobiliário
# Local de produção
#
# Brasil | Minas Gerais
# Data de produção
#
# Século XVIII
# Procedência
#
# Sabará - Casa de Câmara e Cadeia
# Autor
#
# Não identificado
# Material/Técnica
#
# couro lavrado | madeira | marcenaria | metal
# Palavras-chave
#
# brasil | minas gerais | mobiliário | século xix | século xviii
# Fotógrafo
#
# André Brasil
# Data da fotografia
#
# 2007
# Esfera de proteção legal
#
# Federal
# Tipo de tombamento
#
# Tombamento em conjunto
# Marcas/Inscrições
#
# “Vila Real de N. S. Da Conceição Do Sabará”
# Dimensões
#
# Altura (cm): 134,0 Largura (cm): 57,0 Comprimento (cm): Profundidade (cm): 5,08 Diâmetro (cm): Peso (g): Circunferência (cm):
# Resumo descritivo
#
# Cadeira de espaldar alto, reclinado, com recortes curvo superior e inferior; revestimento em couro decorado com o brasão das Armas de Portugal, com inscrição circundante, coroado e delimitado por frisos curvos, volutas, guirlandas de flores e acantos sinuosos, com dois putos inferiores a maneira de atlantes; contorno em friso de lingüeta, com palmeta superior; tacheado miúdo na frente e laterais; com arremate de pináculos nas quinas; assento de formato trapezoidal, mas de desenho curvo, revestido por couro, com decoração em volutas, acantos sinuosos, conchas e palmetas, guirlanda de flores e dois leões alados; contorno em friso de lingüeta, com a borda moldurada; pernas dianteiras com joelhos de saída, contornadas por frisos; pernas traseiras recurvadas e cilíndricas; amarração em “H” sinuoso, com travessas emolduradas; a traseira cilíndrica; pés cônicos, torneados.
# Características técnicas
#
# Cadeira em jacarandá, composta por cerca de 20 partes em madeira recortada e torneada, encaixadas e fixadas por cavilhas; assento e espaldar revestidos em couro lavrado; tacheado miúdo e pináculos em metal amarelo; assento de encaixe.
# Características estilísticas
#
# Cadeira dita de Sola, fazendo parte de conjunto que pertenceu à antiga Câmara e Cadeia da Vila de Sabará, no período colonial; de fatura esmerada, com desenho elegante, de espaldar alto, assento curvo, pernas com joelho e amarração em “H”, toda revestida em couro lavrado, com decoração esmerada, ao gosto barroco D. João V, com acantos, conchas, palmetas, Armas da Coroa portuguesa, figuras de atlantes e leões alados.
# Características iconográficas/ornamentais
#
# Armas da Coroa portuguesa, atlantes, leões alados e decoração típica do estilo D. João V, com acantos, conchas, palmetas, acantos sinuosos e lingüetas; tacheado miúdo e pináculos.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 18-01-1975; Ficha de Conservação e Restauração de 19-03-1990; Ficha Topográfica 1991-1997. CANTI, Tilde. O móvel no Brasil. Origem, evolução e características. Rio de Janeiro, Editora Agir/Lisboa, Fundação Ricardo do Espírito Santo, 1999.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/
# Coletando o item 5207
# Número de registro
#
# 1
# Denominação
#
# Barra de ouro
# Outros números
#
# MO 1  |  Tombo nº 1942.21.01
# Classificação
#
# 03 Objetos Pecuniários
# Local de produção
#
# Mato Grosso
# Data de produção
#
# 1816 | Século XIX
# Procedência
#
# São Paulo
# Modo de aquisição
#
# Compra
# Data de aquisição
#
# 15/09/1942
# Autor
#
# Casa de Fundição de Mato Grosso
# Conjunto com nº
#
# 2 | 3 | 4 | 5 | 6
# Material/Técnica
#
# ouro fundido
# Palavras-chave
#
# brasil | fundição | mato grosso | século xix
# Esfera de proteção legal
#
# Federal
# Tipo de tombamento
#
# Tombamento em conjunto
# Marcas/Inscrições
#
# 23 - N 659 – 6 – 5 – 3 – 54 – 1816; As Armas de Portugal com a inscrição Mato Grosso e a Esfera Armilar; As iniciais IDRF ou IDBF
# Dimensões
#
# Altura (cm): Largura (cm): 2,8 Comprimento (cm): 22,0 Profundidade (cm): 1,4 Diâmetro (cm): Peso (g): + de 1500,0 Circunferência (cm):
# Resumo descritivo
#
# Barra retangular irregular e grossa. Em uma face apresenta as Armas da Coroa, o no da Barra (659), a data (1816), a marca do ourives ensaiador (IDRF ou IDBF), a marca do toque e do quilate (23), a marca de um grão (a flor), e o peso 6-5-3-54 (seis marcos, cinco onças, três oitavas e cinqüenta e quatro grãos). Na outra face, a Esfera Armilar.
# Características técnicas
#
# Peça em ouro fundido e marcado.
# Características estilísticas
#
# Barra de ouro de 23 quilates fundida na Antiga Casa de Fundição de Mato Grosso no ano de 1816.
# Características iconográficas/ornamentais
#
# Iconografia: Armas da Coroa Portuguesa com as cinco quinas rodeadas por sete castelos entre ramos de oliveira, coroado por cima; a Esfera Armilar.
# Dados históricos
#
# Esta barra de ouro fazia parte de um célebre tesouro encontrado em Jundiaí – São Paulo, por volta de 1926. O tesouro foi encontrado sob o assoalho de uma casa pertencente a um tropeiro que fazia muitas viagens a Goiás e Mato Grosso. Os novos proprietários da casa encontraram o tesouro e venderam grande parte dele (moedas e outras barras de ouro) ao antigo Banco de Comércio e Industria de São Paulo. A referida barra, no entanto, foi negociada pela Casa Marcellino e oferecida inicialmente ao numismata José Bento de Carvalho da cidade de Santos, mas o negócio não foi fechado; depois, foi oferecida ao Sr. João Kurk de São Paulo, que a adquiriu imediatamente, ficando em seu poder durante 12 anos. Depois de seu falecimento, em 1937, a barra passou ao sobrinho Alfredo Kurth, que a vendeu ao Sr. Diogo de Toledo Lara. Este conservou a barra por dois anos, passando depois para as mãos do colecionador-numismata Hermann Porcher de São Paulo, de quem foi adquirida pelo SPHAN, em 15 de setembro de 1942, por CR$ 14.716,80.
# Referências bibliográficas/arquivísticas
#
# Ficha Cadastral de 05-01-1972; Ficha de Conservação e Restauração de 05-03-1990; Ficha Topográfica de 23-04-1991 e agosto de 1996. Ficha de Remanejamento, com várias datas, sendo a última de agosto de 1990. Duas fotos P&B (18 x 12,5) números 171 e 173. Documento datilografado, com o histórico da barra, assinado pelo numismata Hermann Porcher, datado de janeiro de 1940, e que se encontra anexado a pasta catalográfica da peça.
# Observações
#
# Segundo informações que se encontram na Ficha Cadastral a barra foi comprada no Rio de Janeiro por CR$ 199,50 em 15 de setembro de 1942, pelo então Diretor do SPHAN, Rodrigo de Melo Franco de Andrade.
# Condições de reprodução
#
# Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/

# %%
rows
# Out:
# [['Número de registro', '729'],
#  ['Denominação', 'Relicário'],
#  ['Título', 'Braço relicário'],
#  ['Outros números', 'MO 629 | Tombo nº 1950.02.37'],
#  ['Classificação', '09 Objetos Cerimoniais > 09.3 Objeto de Culto'],
#  ['Local de produção', 'Brasil | Minas Gerais'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'Ouro Preto - Minas Gerais'],
#  ['Autor', 'Não identificado'],
#  ['Conjunto com nº', '629'],
#  ['Material/Técnica', 'dourada | madeira esculpida | policromada'],
#  ['Palavras-chave',
#   'brasil | escultura | minas gerais | religião | século xviii'],
#  ['Fotógrafo', 'André Brasil'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Dimensões',
#   'Altura (cm): 38,0 Largura (cm): 10,2 Comprimento (cm): Profundidade (cm): 9,2 Diâmetro (cm): Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Relicário na forma de um braço erguido, com a mão (direita) aberta, mas com o dedo mínimo dobrado na ponta; vestido por uma manga comprida, com pregas grossas; padronagem em acantos e esgrafitado dourado; com uma dobra verde na ponta; centro com um nicho elíptico, de fundo vermelho, com a boca delimitada por um entalhe em quatro volutas e frisos curvos; Base quadrangular, moldurada e frisada, dourada com a parte inferior em vermelho.'],
#  ['Características técnicas',
#   'Objeto esculpido em um só bloco de madeira, dourada e policromada em vermelho, verde e bege (na carnação da mão).'],
#  ['Características estilísticas',
#   'Objeto de provável origem mineira, de boa fatura, datável do século XVIII, com decoração e policromia ao gosto do barroco da 1ª metade.'],
#  ['Características iconográficas/ornamentais',
#   'Relicário em forma de uma mão.'],
#  ['Dados históricos',
#   'RELICÁRIO é uma urna ou cofre destinado a guarda de relíquias. RELÍQUIA é tudo aquilo que constitui o corpo físico de um santo (ossos, cabelos, dentes, etc.) ou algo que tenha entrado em contato com ele (partes de suas roupas, pertences pessoais, poeira de seu túmulo, etc). No século IV, estabeleceu-se que seria necessária a presença de uma relíquia para a sagração de uma igreja. Desse modo, pode-se dizer que o culto às relíquias foi o responsável direto pelo surgimento do culto às imagens de santos. Tal fato estimulou a multiplicação das relíquias, e mais do que isto, do comércio em torno delas. Isto implicou em muitas falsificações e criações fantasiosas. Durante a Idade Média, cabeças de São João Batista surgiram às dezenas; a crista do galo que cantou na negação de Pedro, às centenas; ossos dos santos, aos milhares. No entanto, o mais espetacular caso de relíquias, refere-se aos instrumentos de martírio de Jesus Cristo – as armas Christi, como são conhecidas. Consta que São Luís Rei de França, durante a sétima cruzada (séc. XIII), havia comprado em Constantinopla alguns desses instrumentos, como os cravos e a coroa de espinhos, e os levado para o Ocidente. Mas, misteriosamente, tais relíquias reapareceram na antiga capital do Império Bizantino algum tempo depois.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha de Inventário de 24-11-1989; Ficha de Conservação e Restauração de 23-11-1990; Ficha Topográfica 1997. FREEDBERG, David. El poder de las imágenes. Madrid, Cátedra, 1992, p. 119. DAMASCENO, Sueli. Glossário de bens imóveis (Igrejas de Ouro Preto). Ouro Preto, Instituto de Artes e Cultura/UFOP, 1987.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '718'],
#  ['Denominação', 'Porcelana'],
#  ['Título', 'Jarro para barbear'],
#  ['Outros números', 'MO 392 | Tombo nº 1950.15.02'],
#  ['Classificação', '12 Objetos Pessoais > 12.3 Artigo de Toalete'],
#  ['Local de produção', 'China'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'São Paulo'],
#  ['Autor', 'Não identificado'],
#  ['Conjunto com nº', '392'],
#  ['Material/Técnica', 'cerâmica policromada | dourada'],
#  ['Palavras-chave',
#   'artigo de toalete | brasil | minas gerais | oriente | século xviii'],
#  ['Fotógrafo', 'André Brasil'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Dimensões',
#   'Altura (cm): 21,0 Largura (cm): Comprimento (cm): Profundidade (cm): Diâmetro (cm): 12,0 Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Jarro de pé circular, com dois frisos ocres; bojo com a parte inferior mais cheia e a superior cilíndrica, com decoração em flores alaranjadas e beges, com detalhes dourados, botões de flores cinzas e ramos com folhas verdes, cinzas e beges; borda circundada por duplo friso, com pequeno bico; alça auriforme, decorada por flor e elementos sinuosos, em tons laranja; com folhagens junto a sua base.'],
#  ['Características técnicas',
#   'Cerâmica em porcelana policromada nos tons vermelho, laranja, ocre, bege, cinza, verde e dourado.'],
#  ['Características estilísticas',
#   'Jarro que compõe conjunto de barbear, em Porcelana da Companhia das Índias, datável do século XVIII, de origem chinesa, decorada em motivos florais, colorida e policromada.'],
#  ['Características iconográficas/ornamentais',
#   'Flores, ramos com folhas picotadas, botões de flores, frisos.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 26-03-1975; Ficha de Conservação e Restauração de 19-10-1990; Ficha Topográfica 1991-1997; 2 fotos P&B. MOUTINHO, Stella Rodrigo Octavio et alii. Dicionário de Artes Decorativas e Decoração de Interiores. Rio de Janeiro. Ed. Nova Fronteira, 1999.'],
#  ['Observações', 'Conjunto adquirido em São Paulo'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '699'],
#  ['Denominação', 'Escultura Religiosa'],
#  ['Título', 'Menino Jesus'],
#  ['Outros números', 'MO 699 | Tombo nº 1975.02.59 '],
#  ['Classificação', '02 Artes Visuais/Cinematográfica > 02.3 Escultura'],
#  ['Local de produção', 'Brasil | Minas Gerais'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'Não identificada'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'dourada | madeira esculpida | policromada'],
#  ['Palavras-chave', 'escola mineira | escultura | religião | século xviii'],
#  ['Fotógrafo', 'André Brasil'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Dimensões',
#   'Altura (cm): 28,0 Largura (cm): 11,0 Comprimento (cm): Profundidade (cm): 11,0 Diâmetro (cm): Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Figura esculpida do Menino Deus, de pé, nu, em posição frontal, de cabeça erguida, com os olhos à frente; cabelos dourados; braço esquerdo flexionado lateralmente, com a mão de segurar; braço direito flexionado à frente, com a mão de abençoar; perna esquerda flexionada e a outra reta; pés em ângulo;'],
#  ['Características técnicas',
#   'Menino Deus esculpido em uma só parte de madeira, pregado na base, policromado em bege, vermelho, azul e dourado nos cabelos.'],
#  ['Características estilísticas',
#   'Escultura de tratamento razoável, com a anatomia adiposa, rosto cheio, a boca com os lábios em recortes de bico e os membros roliços. De origem mineira, datável do século XVIII.'],
#  ['Características iconográficas/ornamentais',
#   'As representações em separado do Menino Jesus (não no colo da Virgem Maria, como é usual) são apreciadas a partir da Idade Média. Nelas, ele brinca com um pássaro ou segura um cacho de uvas. As representações do Menino acompanhado do globo terrestre (o Menino Deus, como são denominadas), já antes usual, só ganha grande popularidade no século XVI, difundidas especialmente na Itália e na Espanha. Nelas, o Menino aparece geralmente nu, de pé, tendo a mão direita de abençoar e a outra levando o globo terrestre.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha de Inventário de 13-08-1989; Ficha de Conservação e Restauração de 23-11-1990; Ficha Topográfica de 1991 a 1994. HENZ-MOHR, Gerd. Dicionário dos símbolos. São Paulo, Paulus, 1994.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '679'],
#  ['Denominação', 'Tamborete sanitário'],
#  ['Outros números', 'MO 679 | sem nº tombo'],
#  ['Classificação', '05 Interiores > 05.5 Peça de Mobiliário'],
#  ['Local de produção', 'Brasil | Minas Gerais'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'Desconhecida'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'couro | madeira recortada'],
#  ['Palavras-chave',
#   'brasil | minas gerais | mobiliário | século xviii | usos e costumes'],
#  ['Fotógrafo', 'Daniel Mansur'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Tipo de tombamento', 'Tombamento em conjunto'],
#  ['Dimensões',
#   'Altura (cm): 48,0 Largura (cm): 36,0 Comprimento (cm): Profundidade (cm):36,0 Diâmetro (cm): Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Tamborete de assento quadrado, revestido por couro, com uma abertura circular ao meio; pernas de secção quandragular e lisas, afinadas inferiormente; amarração em travessas retas.'],
#  ['Características técnicas',
#   'Móvel em madeira, composto de 12 partes de madeira recortada, encaixadas e coladas; assento revestido de couro, que era fixado originalmente por tachas metálicas, com um recorte circular ao meio.'],
#  ['Características estilísticas',
#   'Tamborete para uso sanitário, característico do período colonial, de confecção rústica, com assento em couro cru.'],
#  ['Características iconográficas/ornamentais', 'Todo liso'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha de Inventário de 01-09-1990; Ficha de Conservação e Restauração de 20-04-1990; Ficha Topográfica 1991-1996'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '672'],
#  ['Denominação', 'Maço de calceteiro'],
#  ['Outros números', 'MO 672 | Tombo nº 1950.31.58'],
#  ['Classificação', '06 Trabalho > 06.8 Equipamento de Uso Geral'],
#  ['Local de produção', 'Brasil | Minas Gerais'],
#  ['Data de produção', 'Século XIX | Século XVIII'],
#  ['Procedência', 'Região de Sabará'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'madeira recortada'],
#  ['Palavras-chave',
#   'equipamento de uso geral | minas gerais | século xix | século xviii'],
#  ['Fotógrafo', 'Daniel Mansur'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Tipo de tombamento', 'Tombamento em conjunto'],
#  ['Dimensões',
#   'Altura (cm): 79 Largura (cm): 30 Comprimento (cm): Profundidade (cm): 20 Diâmetro (cm): Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Bloco trapezoidal, liso, de cuja superfície superior se eleva um cabo comprido, de secção cilíndrica.'],
#  ['Características técnicas',
#   'Peça em madeira recortada, composta de duas partes encaixadas.'],
#  ['Características estilísticas',
#   'Instrumento rústico, de origem local, datável do século XVIII ou XIX, utilizado para socar pedras na construção de ruas.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha de Inventário de 04-01-1990; Ficha de Conservação e Restauração de 23-11-1990; Ficha Topográfica 1991-1996.'],
#  ['Observações', 'O mesmo que malho'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '667'],
#  ['Denominação', 'Picúa'],
#  ['Outros números', 'MO 667 sem nº tombo '],
#  ['Classificação', '06 Trabalho > 06.6 Equipamento de Mineração'],
#  ['Local de produção', 'Brasil | Minas Gerais'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', '[Diamantina]'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'madeira recortada'],
#  ['Palavras-chave', 'brasil | minas gerais | mineração | século xviii'],
#  ['Fotógrafo', 'André Brasil'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Dimensões',
#   'Altura (cm): 12,0 Largura (cm): Comprimento (cm): Profundidade (cm): Diâmetro (cm): 13,0 Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Recipiente em formato de canudo liso, com tampa semi-esférica, de encaixar.'],
#  ['Características técnicas',
#   'Peça em madeira recortada, em duas partes, com tampa de encaixe.'],
#  ['Características estilísticas',
#   'Recipiente para guarda de diamantes ou ouro, denominado de picuá, em madeira, simples; datável do século XVIII ou XIX e originário da região de Diamantina.'],
#  ['Características iconográficas/ornamentais', 'Sem ornamentos'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha de Inventário de 06-06-1990; Ficha de Conservação e Restauração de 22-11-1990; Ficha Topográfica 1991-1996.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '641'],
#  ['Denominação', 'Escultura Religiosa'],
#  ['Título', 'Santa Catarina de Siena'],
#  ['Outros números', 'MO 641 | Tombo nº 1950.02.10              '],
#  ['Classificação', '02 Artes Visuais/Cinematográfica > 02.3 Escultura'],
#  ['Local de produção', 'Brasil | Minas Gerais'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', '[Igreja de Sabará]'],
#  ['Autor', 'Não identificado'],
#  ['Conjunto com nº', '427'],
#  ['Material/Técnica', 'dourada | madeira esculpida | policromada'],
#  ['Palavras-chave', 'escola mineira | escultura | religião | século xviii'],
#  ['Fotógrafo', 'Daniel Mansur'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Tipo de tombamento', 'Tombamento em conjunto'],
#  ['Dimensões',
#   'Altura (cm): 47,0 Largura (cm): 23,5 Comprimento (cm): Profundidade (cm): 18,5 Diâmetro (cm): Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Figura feminina, meia-idade, de pé, em posição frontal; cabeça inclinada à direita, olhos abaixados; braços flexionados a frente, sem as mãos; perna direita flexionada e a esquerda reta; pés em ângulo; Vestida com hábito e escapulário brancos, padronagem em motivos fitomorfos e florais dourados, com punções; cobrindo a cabeça uma coifa branca, de mesma padronagem, e véu preto; capa preta, que envolve a parte inferior do corpo, com padronagem em acantos e esgrafitos dourados; calça sapatos pretos com confetes dourados. Base elíptica vermelha, com quatro bicos, friso meia-cana invertida ao meio e friso dourado na borda superior.'],
#  ['Características técnicas',
#   'Imagem esculpida em um só bloco de madeira, dourada e policromada em vermelho, preto, branco e bege; punções e esgrafitos; furo na cabeça para resplendor.'],
#  ['Características estilísticas',
#   'Imagem de provável origem mineira, datável de meados do século XVIII, de boa fatura, com a composição bem proporcional, movimento contido, com panejamento em dobras de caimento reto; rosto inexpressivo, de olhos pintados, nariz fino, boca de lábios apertados e pouco recortados; o estofamento, bem elaborado, em acantos e folhagens grandes imitando adamascado, é ao gosto do barroco.'],
#  ['Características iconográficas/ornamentais',
#   'Imagem designada como Santa Catarina de Siena, santa dominicana que viveu no século XV (morreu em 1380, com 33 anos). Como atributos mais freqüentes pode ter uma coroa de espinhos ou rosas – a santa foi uma estigmatizada como São Francisco de Assis –, um crucifixo, um coração, um rosário na mão ou no cinto do hábito ou ainda um livro (a santa deixou vários escritos de cunho teológico, apesar de não saber ler e escrever). É comum vermos a santa ao lado de São Domingos na cena em que este recebe de Nossa Senhora o Rosário* (*)Como em uma bandeira pintada pertencente ao acervo do Museu.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 27-11-1989; Ficha de Conservação e Restauração 11-09-1990; Ficha Topográfica 1991-1996. CERINOTTI, Angela. Santos e Beatos de ontem e hoje. São Paulo, Globo, 2004 ROIG, Juan Ferrando. Iconografía de los Santos. Barcelona, Ediciones Omega, 1950.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '630'],
#  ['Denominação', 'Escultura Religiosa'],
#  ['Título', 'Santa Cecília'],
#  ['Classificação', '02 Artes Visuais/Cinematográfica > 02.3 Escultura'],
#  ['Local de produção', 'Brasil | Minas Gerais'],
#  ['Data de produção', 'Século XIX'],
#  ['Procedência', 'Minas Gerais'],
#  ['Modo de aquisição', 'Doação'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'madeira esculpida | policromada'],
#  ['Palavras-chave', 'escola mineira | escultura | religião | século xix'],
#  ['Fotógrafo', 'Arquivo Museu do Ouro'],
#  ['Data da fotografia', '2020'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Dimensões',
#   'Altura (cm): 46,0 Largura (cm): 32,0 Comprimento (cm): Profundidade (cm): 18,0 Diâmetro (cm): Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Imagem de roca desmontada, de uma figura feminina, composta do busto e de dois braços. Busto semi-esculpido, carnado de rosa, com os seios delineados; quatro recortes inferiores para fixação das ripas que formam o corpo da figura, e laterais dos ombros com pinos para fixação dos braços. Braços em duas partes unidas por articulação de bolacha nos cotovelos; parte posterior só desbastada; parte anterior (antebraço) carnada de rosa, terminado nas mãos, ambas tendo o anular e o médio dobrados, e os outros estendidos; na mão esquerda falta o dedo mínimo.'],
#  ['Características técnicas',
#   'Imagem de roca (ou de vestir) esculpida em madeira, composta de seis partes encaixadas; policromia em rosa pálido (carnação); marrom (cabelos e olhos) e vermelho (lábios).'],
#  ['Características estilísticas',
#   'Escultura de boa qualidade técnica, datável do século XIX, de rosto arredondado, olhos elípticos, de interior raso; sobrancelhas pintadas; nariz com a linha da frente chanfrada e ponta levemente arredondada; lábios de recortes suaves; mãos de dedos longilíneos e arredondados.'],
#  ['Características iconográficas/ornamentais',
#   'Iconografia: Mártir romana de família nobre. Forçada a casar, conseguiu converter o noivo S. Valentino ao Cristianismo e a levar vida casta e cristã. Recusando-se a sacrificar aos deuses, foi supliciada e, depois de morrer, sepultada no cemitério de Calixto. É representada tocando um instrumento musical ou, em alguns casos, a ouvir um anjo que toca. O seu atributo pessoal é um instrumento musical – uma lira ou um órgão de tubos, como é comum vê-la em Minas Gerais. Uma marca de sangue em volta do pescoço alude à sua degolação.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha de Inventário de 24-11-1989; 2 Fichas de Conservação e Restauração de 24-11-1989; 2 Fichas Topográfica de 1991. 14 fotos coloridas 25x18. TAVARES, Jorge Campos. Dicionário de Santos. Porto, Lello & Irmãos Editores, 1990.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '629'],
#  ['Denominação', 'Relicário'],
#  ['Título', 'Braço relicário'],
#  ['Outros números', 'MO 629 | Tombo nº 1950.02.37'],
#  ['Classificação', '09 Objetos Cerimoniais > 09.3 Objeto de Culto'],
#  ['Local de produção', 'Brasil | Minas Gerais'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'Ouro Preto - Minas Gerais'],
#  ['Autor', 'Não identificado'],
#  ['Conjunto com nº', '729'],
#  ['Material/Técnica', 'dourada | madeira esculpida | policromada'],
#  ['Palavras-chave',
#   'brasil | escultura | minas gerais | religião | século xviii'],
#  ['Fotógrafo', 'André Brasil'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Dimensões',
#   'Altura (cm): 39,0 Largura (cm): 11,0 Comprimento (cm): Profundidade (cm): 9,2 Diâmetro (cm): Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Relicário na forma de um braço erguido, com a mão (esquerda) aberta, mas com o dedo mínimo dobrado na ponta; vestido por uma manga comprida, com pregas grossas; padronagem em acantos e esgrafitado dourado; com uma dobra verde na ponta; centro com um nicho elíptico, de fundo vermelho, com a boca delimitada por um entalhe em quatro volutas e frisos curvos; Base quadrangular, moldurada e frisada, dourada com a parte inferior em vermelho.'],
#  ['Características técnicas',
#   'Objeto esculpido em um só bloco de madeira, dourada e policromada em vermelho, verde e bege (na carnação da mão).'],
#  ['Características estilísticas',
#   'Objeto de provável origem mineira, de boa fatura, datável do século XVIII, com decoração e policromia ao gosto do barroco da 1ª metade.'],
#  ['Características iconográficas/ornamentais',
#   'Relicário em forma de uma mão. RELICÁRIO é uma urna ou cofre destinado a guarda de relíquias. RELÍQUIA é tudo aquilo que constitui o corpo físico de um santo (ossos, cabelos, dentes, etc.) ou algo que tenha entrado em contato com ele (partes de suas roupas, pertences pessoais, poeira de seu túmulo, etc). No século IV, estabeleceu-se que seria necessária a presença de uma relíquia para a sagração de uma igreja. Desse modo, pode-se dizer que o culto às relíquias foi o responsável direto pelo surgimento do culto às imagens de santos. Tal fato estimulou a multiplicação das relíquias, e mais do que isto, do comércio em torno delas. Isto implicou em muitas falsificações e criações fantasiosas. Durante a Idade Média, cabeças de São João Batista surgiram às dezenas; a crista do galo que cantou na negação de Pedro, às centenas; ossos dos santos, aos milhares. No entanto, o mais espetacular caso de relíquias, refere-se aos instrumentos de martírio de Jesus Cristo – as armas Christi, como são conhecidas. Consta que São Luís Rei de França, durante a sétima cruzada (séc. XIII), havia comprado em Constantinopla alguns desses instrumentos, como os cravos e a coroa de espinhos, e os levado para o Ocidente. Mas, misteriosamente, tais relíquias reapareceram na antiga capital do Império Bizantino algum tempo depois.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha de Inventário de 24-11-1989; Ficha de Conservação e Restauração de 21-11-1990; Ficha Topográfica de 1997. FREEDBERG, David. El poder de las imágenes. Madrid, Cátedra, 1992, p. 119. DAMASCENO, Sueli. Glossário de bens imóveis (Igrejas de Ouro Preto). Ouro Preto, Instituto de Artes e Cultura/UFOP, 1987.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '615'],
#  ['Denominação', 'Flauta e estojo'],
#  ['Outros números', 'MO 615 |  sem nº tombo'],
#  ['Classificação', '06 Trabalho > 06.10 Equipamento Musical'],
#  ['Local de produção', '[Brasil]'],
#  ['Data de produção', 'Século XIX'],
#  ['Procedência', 'Sabará'],
#  ['Modo de aquisição', 'Compra'],
#  ['Data de aquisição', '1982'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'fundição | madeira | metal | recorte | torneado'],
#  ['Palavras-chave', 'brasil | instrumento musical | século xix'],
#  ['Fotógrafo', 'Acervo Museu do Ouro'],
#  ['Data da fotografia', '2020'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Dimensões',
#   'Altura (cm): Largura (cm): Comprimento (cm): 63,0 Profundidade (cm): Diâmetro (cm): 3,0 Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Flauta em ébano, de secção cilíndrica, dividida em três partes, com onze (11) registros e cinco (chaves) em metal prateado; a separação das partes é feita por aros em metal prateado. Estojo retangular, envernizado, com dois fechos de pressão e alça retangular ligeiramente curva; interior revestido por espuma e feltro azul, com dois suportes recortados em semicírculos, onde se encaixam as partes desmontadas da flauta.'],
#  ['Características técnicas',
#   'Flauta em ébano, torneado, desmontável em 5 partes; chaves* e aros em metal prateado (ou prata?), parafusados; estojo em madeira recortada, composta de 10 partes encaixadas e coladas; revestimento em feltro azul e espuma; falta a embocadura **.'],
#  ['Características estilísticas',
#   'Flauta datável do século XIX, de fabricação seriada.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha de Inventário de 23-11-1989/ 2 Fichas de Conservação e Restauração de 20-11-1990/ 4 Fichas Topográfica 1991 a 1993;'],
#  ['Observações',
#   '(*) A chave é a peça que serve para fechar ou abrir os orifícios; compõe-se de concha, haste e espátula. (**) A embocadura á parte superior dos instrumentos de sopro que se introduz na boca Comprada em 30/09/1982, de Benjamim Couto Lima e Luiz Pereira Lamego, de Sabará.Participou da exposição SESC/PMS – 1993, na Casa de Borba Gato. Medidas do estojo: 5,0 x 12,5 x 28,7 cm'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '606'],
#  ['Denominação', 'Tesoura de ourives'],
#  ['Outros números', 'MO 606 | sem nº tombo'],
#  ['Classificação', '06 Trabalho > 06.3 Equipamento de Artistas/Artesãos'],
#  ['Local de produção', 'Brasil'],
#  ['Data de produção', 'Século XIX | Século XVIII'],
#  ['Procedência', 'Desconhecida'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'ferro fundido'],
#  ['Palavras-chave',
#   'brasil | minas gerais | ourivesaria | século xix | século xviii'],
#  ['Fotógrafo', 'Daniel Mansur'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Tipo de tombamento', 'Tombamento em conjunto'],
#  ['Dimensões',
#   'Altura (cm): Largura (cm): 5,0 Comprimento (cm): 16,5 Profundidade (cm): 1,5 Diâmetro (cm): Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Tesoura com duas hastes de extremos recurvados para dentro, retorcidas no outro extremo, onde se cruzam, formando a parte cortante, terminada em bico.'],
#  ['Características técnicas',
#   'Peça composta por duas partes de ferro fundido, unidas por pino.'],
#  ['Características estilísticas',
#   'Objeto datável do século XVIII ou XIX, de fatura rústica.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha de Inventário de 23-11-1989; Ficha de Conservação e Restauração de 20-11-1990; Ficha Topográfica 1991.'],
#  ['Observações', 'Tesoura ou alicate de ourives'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '534'],
#  ['Denominação', 'Caixa de Santos Óleos'],
#  ['Outros números', 'MO 534 | Tombo nº 1975.13.24'],
#  ['Classificação', '09 Objetos Cerimoniais > 09.3 Objeto de Culto'],
#  ['Local de produção', '[Minas Gerais]'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'Esmeralda'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'prata lavrada'],
#  ['Palavras-chave',
#   'brasil | minas gerais | ourivesaria | religião | século xviii'],
#  ['Fotógrafo', 'André Brasil'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Marcas/Inscrições', '“P” e “C”'],
#  ['Dimensões',
#   'Altura (cm):11,0 Largura (cm):5,0 Comprimento (cm):11,5 Profundidade (cm): Diâmetro (cm): Peso (g): 365,0 Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Caixa elíptica, com centro gravado em motivos fitomorfos com flores; borda frisada; tampa abaulada, gravada em motivos fitomorfos, com flores-de-lis e cartela oval de interior liso; com pequena pega torneada ao alto. Interior com um tampo superior, dividido em três compartimentos circulares, onde se encaixam dois frascos dos santos óleos. Ambos de formato cilíndrico, com friso inferior, terminado em um gargalo duplamente frisado, com tampa de borda estriada; marcados, um, com inscrição superior “P” e o outro, com “C”.'],
#  ['Características técnicas',
#   'Prata martelada, repuxada e gravada; dobradiça na tampa; pega fundida e soldada; frascos encaixados.'],
#  ['Características estilísticas',
#   'Peça em prata, datável do século XVIII, com decoração barroca, em acantos e flores; não apresenta marcas, o que faz supor se tratar de uma peça mineira.'],
#  ['Características iconográficas/ornamentais',
#   'Acantos, flores, torneados, cartela e frisos.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto. Caixa para os santos óleos é o recipiente usado para guardar os três distintos óleos do Batismo, do Crisma e do Sacramento dos Enfermos. Em número de três, costumam trazer inscrições indicativas de cada conteúdo: OS – Oleum Sanctum ou Óleo dos Catecúmenos; SC – Sanctum Chrisma; e OI – Oleum Infirmorum. Nos frascos dessa caixa as inscrições “C” e “P”'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração 12-11-1990; Ficha Topográfica 1991-1997. DAMASCENO, Sueli. Glossário de Bens Móveis (igrejas mineiras). Ouro Preto, UFOP/Instituto de Artes e Cultura, 1987.'],
#  ['Observações',
#   'Medidas complementares: Frasco “P” = 7,2 x Ø = 3 x 40 gr; Frasco “C” = 7,2 x Ø = 3 x 45 gr'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '533'],
#  ['Denominação', 'Ostensório'],
#  ['Outros números', 'MO 533 | Tombo nº 1975.13.23'],
#  ['Classificação', '09 Objetos Cerimoniais > 09.3 Objeto de Culto'],
#  ['Local de produção', '[Brasil]'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'Pernambuco'],
#  ['Modo de aquisição', 'Compra'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'ouro lavrado | prata | vidro'],
#  ['Palavras-chave',
#   'brasil | ourivesaria | pernambuco | religião | século xviii'],
#  ['Fotógrafo', 'André Brasil'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Dimensões',
#   'Altura (cm): 59,0 Largura (cm): 17,5 Comprimento (cm): Profundidade (cm): 16,2 Diâmetro (cm): 16,2 Peso (g): 3100,0 Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Ostensório em prata dourada, com a base campanulada, em frisos salientes; coluna torneada em nós, frisos e estrangulamentos; copo de bojo semi-esférico, decorado em seis molduras salientes e gravações curvas; nele se encaixa o corpo da custódia, de base com extremidades recurvadas, faces decoradas com folhas de acantos e cartelas centrais com cabeças de anjos; nas quinas (4) colunas de socos em guilhochês, listel em caneluras e capitel de acantos; centro com a superfície gravada em círculo de acantos; visor circular liso, com um lado envidraçado; no interior uma luneta de ouro em crescente, com três cabeças de anjos; parte superior em cimalha retangular, com as frentes abauladas, revestidas em acantos e flores; arremate em cúpula semi-esférica, revestida por acantos em relevo, encimada por cruz latina, de traves torneadas com acantos; ladeando a cúpula, quatro pináculos torneados, que aparecem também na parte inferior da base.'],
#  ['Características técnicas',
#   'Peça em prata e ouro fundidos, martelados, repuxados e cinzelados, desmontável em 20 partes, atarraxadas; visor com porta envidraçada; prata banhada a ouro; copo, visor e luneta em ouro.'],
#  ['Características estilísticas',
#   'Ostensório de provável origem brasileira, já que não apresenta nenhuma marca, originária de Pernambuco, com a decoração ao gosto barroco, de acantos, cartelas, volutas, guilhochês e cabeças de anjos;'],
#  ['Características iconográficas/ornamentais',
#   'Frisos, nós, acantos, cartelas, volutas, colunas com guilhochês, caneluras e capitéis de acantos, flores, pináculos e molduras; cabeças de anjos e cruz latina; lua crescente.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração 12-11-1990; Ficha Topográfica 1991-1996; 1 Foto P&B nº 307.'],
#  ['Observações', 'Também denominado Custódia.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '532'],
#  ['Denominação', 'Ostensório'],
#  ['Outros números', 'MO 532 | Tombo nº 1975.13.25'],
#  ['Classificação', '09 Objetos Cerimoniais > 09.3 Objeto de Culto'],
#  ['Local de produção', '[Minas Gerais]'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'Santa Bárbara'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'prata lavrada'],
#  ['Palavras-chave',
#   'brasil | minas gerais | ourivesaria | religião | século xviii'],
#  ['Fotógrafo', 'André Brasil'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Dimensões',
#   'Altura (cm): 22,5 Largura (cm): 21,0 Comprimento (cm): Profundidade (cm): Diâmetro (cm): 9,5 Peso (g): 455,0 Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Ostensório de base campanulada, com a borda frisada em volutas e ondulados seqüenciados; coluna curta, torneada; visor circular, com a frente envidraçada, circundado por rainonado de raios ondulados mesclados com raios retos, com contorno interno em friso cordão; está ladeado por duas cabeças de anjos e encimado por uma cruz torneada sobre esfera; tampa traseira decorada em motivos fitomorfos, com dobradiça e pequeno fecho; interior com local para encaixe da luneta.'],
#  ['Características técnicas',
#   'Peça em prata martelada, repuxada, fundida e cinzelada, desmontável em cinco partes; cruz, coluna e cabeça de anjos fundidas e soldadas; visor com vidro transparente, encaixado.'],
#  ['Características estilísticas',
#   'Ostensório em prata lavrada, com decoração barroca em volutas, cabeças de anjos, frisos e torneados, datável do século XVIII; não apresenta marcas do ourives e da contrastaria, o que faz supor se tratar de uma peça de origem mineira.'],
#  ['Características iconográficas/ornamentais',
#   'Raionado, cabeças de anjos, cruz latina, friso cordão, volutas, ondulados, torneados e motivos fitomorfos.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração 16-02-1990; Ficha Topográfica 1991; 1 Foto P&B nº 306'],
#  ['Observações', 'Também denominado de Custódia.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '531'],
#  ['Denominação', 'Naveta'],
#  ['Outros números', 'MO 531 | Tombo nº 1950.13.22'],
#  ['Classificação', '09 Objetos Cerimoniais > 09.3 Objeto de Culto'],
#  ['Local de produção', '[Minas Gerais]'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'Vale do Paraopeba'],
#  ['Autor', 'Não identificado'],
#  ['Conjunto com nº', '509'],
#  ['Material/Técnica', 'prata lavrada'],
#  ['Palavras-chave',
#   'brasil | minas gerais | ourivesaria | religião | século xviii'],
#  ['Fotógrafo', 'André Brasil'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Dimensões',
#   'Altura (cm): 14,0 Largura (cm): 7,5 Comprimento (cm): 17,0 Profundidade (cm): Diâmetro (cm): Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Naveta de base elíptica, frisada ao centro, seguida de curta coluna torneada em nós e friso; bojo pseudo cordiforme, circundado por frisos em cês e angras, com arremate de flores e folhagens; fundo puncionado; ao centro, nas duas faces, uma espécie de brasão composto por nuvens, com estrela central e duas outras por cima; superfície superior, com o centro rebaixado, com dobradiça; borda contornada por frisos, com arremate de acantos nas pontas; fundo puncionado em estrelas; uma das metades abre-se em forma de tampa.'],
#  ['Características técnicas',
#   'Peça em prata martelada, repuxada, fundida e cinzelada, composta de três partes; coluna fundida e soldada ao meio; tampa com dobradiça.'],
#  ['Características estilísticas',
#   'Naveta em prata lavrada, de boa execução, datável da segunda metade do século XVIII, com decoração típica da época, em transição do joanino para o rococó, com cês, angras, acantos, flores. Não apresenta marcas do ourives e da contrastaria, o que faz supor se tratar de uma peça mineira.'],
#  ['Características iconográficas/ornamentais',
#   'O brasão com as três estrelas e o monte pode ser o da Ordem Terceira do Carmo; cês, angras, flores, punções, folhagens.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração de 12-11-1990; Ficha Topográfica 1991-1997; 1 Foto P&B nº 305.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '530'],
#  ['Denominação', 'Naveta'],
#  ['Outros números', 'MO 530 | Tombo nº 1950.13.22'],
#  ['Classificação', '09 Objetos Cerimoniais > 09.3 Objeto de Culto'],
#  ['Local de produção', '[Rio de Janeiro]'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'Vale do Paraopeba'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'prata lavrada'],
#  ['Palavras-chave',
#   'brasil | minas gerais | ourivesaria | religião | século xviii'],
#  ['Fotógrafo', 'Daniel Mansur'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Marcas/Inscrições',
#   'Um “B” sobreposto a um “F” (?), um “R” coroado e a marca do toque, em zigue-zague'],
#  ['Dimensões',
#   'Altura (cm): 15 Largura (cm): 8 Comprimento (cm): 19 Profundidade (cm): Diâmetro (cm): 9 Peso (g): 510,0 Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Naveta no formato de uma caravela, com a base circular, revestida por lingüetas; bojo com as laterais imitando emendas do madeirame do casco; proa, mas baixa, arredondada e frisada na frente, com pequena elevação circundante; popa alta, enrolada no extremo, onde aparece revestida por acantos, com desenho de janelas, portas e guilhochês; abre-se como uma tampa; toda borda contornada por friso de cordão; o meio do convés rebaixado em curva, com desenho imitando o madeirame e uma porta; decoração semelhante à da proa.'],
#  ['Características técnicas',
#   'Peça em prata martelada, repuxada, fundida e cinzelada, composta de três partes; base soldada ao bojo; tampa com dobradiça.'],
#  ['Características estilísticas',
#   'Naveta em prata lavrada, de boa execução, com desenho característico do setecentos, no formato de uma caravela, com decoração de acantos, lingüetas e guilhochês. Apresenta marcas do ourives e da contrastaria, sendo esta última identificada com o Rio de Janeiro.'],
#  ['Características iconográficas/ornamentais',
#   'Caravela portuguesa; friso cordão, acantos, lingüetas, guilhochês.'],
#  ['Dados históricos',
#   'Marcas não identificadas; a do ourives pode ser “FBA” ou “FB” sobrepostos; o da contrastaria é com certeza um “R” coroado, relativo a uma marca de contraste do Rio de Janeiro de fins do século XVIII ou início do XIX.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração de 12-11-1990; Ficha Topográfica 1991-1997; VIDAL, Manoel Gonçalves. Marcas de contrastes e ourives portugueses. Lisboa, Imprensa Nacional/Casa da Moeda, 1974, vol. 1.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '525'],
#  ['Denominação', 'Comenda árabe'],
#  ['Outros números', 'MO 525 | Tombo nº 1952.22.01'],
#  ['Classificação', '09 Objetos Cerimoniais > 09.2 Objeto Comemorativo'],
#  ['Local de produção', 'França'],
#  ['Data de produção', 'Século XX'],
#  ['Procedência', 'Desconhecida'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'esmalte | ouro fundido | prata'],
#  ['Palavras-chave', 'frança | objeto comemorativo | século xx'],
#  ['Fotógrafo', 'André Brasil'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Marcas/Inscrições',
#   '“Nº 46/ Kretly/ Palais-Royal/Paris” e inscrições em árabe.'],
#  ['Dimensões',
#   'Altura (cm): Largura (cm): Comprimento (cm): Profundidade (cm): 2,0 Diâmetro (cm): 10,0 Peso (g): 110,0 Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Comenda em forma de uma estrela convexa, com cinco pontas mais destacadas, compostas por inúmeros filetes lanceolados, todos contornados por friso cordão e com relevo em ponta de diamante; ao centro um círculo de aro dourado por fora e um aro intermediário em vermelho com inscrições douradas em árabe; interior dourado, com monograma, também em árabe, dourado e em relevo; ao redor desse círculo sete luas crescentes com estrelas de cinco pontas, também delimitadas por friso cordão e com relevos em ponta de diamante. No verso, dois ganchos e marca de uma presilha maior; e ao meio uma inscrição em francês.'],
#  ['Características técnicas',
#   'Peça em metal branco (prata?), fundido e filigranado, com esmaltado vermelho e partes douradas; partes soldadas.'],
#  ['Características estilísticas',
#   'Comenda com inscrições em árabe, datável do século XX.'],
#  ['Características iconográficas/ornamentais',
#   'Luas crescentes, estrelas, pontas de diamante; friso cordão.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração 12-11-1990; Ficha Topográfica 1991. 4 fotos coloridas numeradas ( a lápis)12, 13 14 e 16.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '524'],
#  ['Denominação', 'Comenda'],
#  ['Título', 'Ordem de Cristo'],
#  ['Outros números', 'MO 524 | Tombo nº 1952.22.02'],
#  ['Classificação', '09 Objetos Cerimoniais > 09.2 Objeto Comemorativo'],
#  ['Local de produção', '[Portugal]'],
#  ['Data de produção', '[Século XVIII]'],
#  ['Procedência', 'Desconhecida'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'esmalte | fundição | martelagem | prata dourada'],
#  ['Palavras-chave', 'objeto comemorativo | portugal | século xviii'],
#  ['Fotógrafo', 'Daniel Mansur'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Tipo de tombamento', 'Tombamento em conjunto'],
#  ['Dimensões',
#   'Altura (cm): 9,0 Largura (cm): 4,5 Comprimento (cm): Profundidade (cm): 0,7 Diâmetro (cm): Peso (g): 50,0 Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Comenda em formato de cruz dourada, com a frente esmaltada em vermelho, com a borda em friso rendilhado; centro com outra cruz, em esmaltado branco, com contorno em friso dourado; parte superior com alça formada por dois êsses e um cê invertido, onde se prende uma argola elíptica chapeada, com a frente ornada em relevo de ramos com flores miúdas.'],
#  ['Características técnicas',
#   'Cruz em prata martelada e fundida, banhada a ouro, com esmaltado branco e vermelho; alça martelada e cinzelada, encaixada.'],
#  ['Características iconográficas/ornamentais', 'Comenda da Ordem de Cristo'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração 12-11-1990; Ficha Topográfica 1991; 1 foto colorida.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '523'],
#  ['Denominação', 'Comenda'],
#  ['Título', '[Ordem dos Cavaleiros do Santo Sepulcro]'],
#  ['Outros números', 'MO 523 |  Tombo nº 1952.22.03'],
#  ['Classificação', '09 Objetos Cerimoniais > 09.2 Objeto Comemorativo'],
#  ['Local de produção', 'Europa'],
#  ['Data de produção', '[Século XVIII]'],
#  ['Procedência', 'Desconhecida'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'esmalte | prata fundida'],
#  ['Palavras-chave', 'europa | objeto comemorativo | século xviii'],
#  ['Fotógrafo', 'Daniel Mansur'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Tipo de tombamento', 'Tombamento em conjunto'],
#  ['Dimensões',
#   'Altura (cm): 9,5 Largura (cm): 4,0 Comprimento (cm): Profundidade (cm): 0,7 Diâmetro (cm): Peso (g): 40,0 Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Comenda em cruz de travessões terminados em ponteiras perpendiculares; centro esmaltado em vermelho, com borda em friso serilhado (frente e verso); entre os ângulos, outras quatro cruzes menores, de mesmo feitio; arremate em uma coroa real, decorada com flores e friso perolado e encimada por globo com cruz latina, com argola circular onde se prende uma alça elíptica chapeada.'],
#  ['Características técnicas',
#   'Comenda em prata fundida e esmaltada em vermelho; coroa, argola e alça encaixadas.'],
#  ['Características iconográficas/ornamentais',
#   'Trata-se da Cruz de Jerusalém que simboliza as cinco chagas de Cristo, que é a sigla da Ordem dos Cavaleiros do Santo Sepulcro.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 27-03-1975; Ficha de Conservação e Restauração 12-11-1990; Ficha Topográfica 1991; 2 fotos coloridas.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '509'],
#  ['Denominação', 'Turíbulo'],
#  ['Outros números', 'MO 509 | Tombo nº 1948.13.20'],
#  ['Classificação', '09 Objetos Cerimoniais > 09.3 Objeto de Culto'],
#  ['Local de produção', '[Minas Gerais]'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'Vale do Paraopeba'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'prata lavrada'],
#  ['Palavras-chave', 'minas gerais | ourivesaria | religião | século xviii'],
#  ['Fotógrafo', 'Daniel Mansur'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Tipo de tombamento', 'Tombamento em conjunto'],
#  ['Dimensões',
#   'Altura (cm): 19,5/90,0 (total) Largura (cm): Comprimento (cm): Profundidade (cm): Diâmetro (cm): 11,5 Peso (g): 930,0 Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Turíbulo de base circular, frisada; bojo abaulado, decorado em três cartelas, circundadas por angras, em cujo interior aparece um brasão encimado por coroa composto por nuvens com uma estrela central e duas outras por cima; envolvimento de acantos que descem da borda, onde aparece um ressalto curvo com orifício, onde se prende a corrente da tampa. Tampa em formato de cúpula, decorada em angras centrando vazados com folhas; envolvimento em folhas de acantos e junto à borda uma alça arrematada por palmeta (duas já substituídas) por onde corre a corrente; arremate m frisos e uma pinha revestida por folhagens. Quatro partes de correntes, presas superiormente a um prato circular, frisado, com orifício central, por onde corre uma das correntes, arrematada por argola.'],
#  ['Características técnicas',
#   'Peça em prata fundida e cinzelada, composta por oito partes; quatro partes de correntes de espinho; duas alças de cobre substituem as originais, em prata.'],
#  ['Características estilísticas',
#   'Naveta em prata lavrada, de boa execução, datável da segunda metade do século XVIII, com decoração típica da época, em transição do joanino para o rococó, com cês, angras, acantos, flores. Não apresenta marcas do ourives e da contrastaria, o que faz supor se tratar de uma peça mineira.'],
#  ['Características iconográficas/ornamentais',
# ...
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '422'],
#  ['Denominação', 'Oratório'],
#  ['Título', 'Oratório com símbolos da Paixão'],
#  ['Outros números', 'MO 422 | Tombo nº 1950.02.30'],
#  ['Classificação', '05 Interiores > 05.5 Peça de Mobiliário'],
#  ['Local de produção', 'Brasil | Minas Gerais'],
#  ['Data de produção', 'Século XIX | Século XVIII'],
#  ['Procedência', 'Antiga capela do Cuiabá-Sabará'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'dourada | entalhada | madeira recortada | policromada'],
#  ['Palavras-chave',
#   'minas gerais | mobiliário | religião | século xix | século xviii'],
#  ['Fotógrafo', 'Daniel Mansur'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Tipo de tombamento', 'Tombamento em conjunto'],
#  ['Marcas/Inscrições', '“INRI”'],
#  ['Dimensões',
#   'Altura (cm):121,0 Largura (cm): 63,0 Comprimento (cm): Profundidade (cm): 35,0 Diâmetro (cm): Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Oratório retangular vertical, com porta de duas bandas, emolduradas, em três almofadas (cada folha) reentrantes, de centro alto, frisado, com fechaduras de espelhos elípticos; parte interna da porta com pinturas representando os símbolos da Paixão: na banda esquerda, de baixo para cima: 1ª - a escada, a lança, a esponja e a corda; 2ª - custódia com coroa de espinhos; 3ª - custódia com a coroa de espinhos; na banda direita: 1ª sem; 2ª cálice com tampa e chicote; 3ª custódia com três cravos. Contorno em molduras douradas, com cimalha superior saliente; arremate em frontão sinuoso, com contorno em cês e êsses ressaltados e interior liso, com vestígio de pintura de uma cartela com três cravos. Parte interna com fundo e laterais com pintura de motivos florais grandes, com flores e botões vermelhos e ocres, com ramos e folhas verdes, alguns enlaçados por fitas vermelhas; fundo em azul; frente emoldurada em pilastras douradas, com capitéis e frisos ressaltados; coroamento em arco seguindo o mesmo desenho das pilastras, com mísula central e cantos em pintura de flores vermelhas.'],
#  ['Características técnicas',
#   'Peça em madeira, composta de 36 partes recortadas, entalhadas, encaixadas e fixadas por cravos; douramento e policromia em vermelho, azul, preto, verde, ocre, amarelo, marrom e branco; ferragem com fechaduras (1), espelhos (2), dobradiças (4) e fechos (2), em ferro fundido; encaixe do tipo rabo-de-andorinha.'],
#  ['Características estilísticas',
#   'Oratório de origem mineira, de composição retilínea, com alguns recortes sinuosos no arremate superior; pintura com motivos simbólicos, de execução de cunho mais popular; datável de fins do século XVIII ou início do XIX.'],
#  ['Características iconográficas/ornamentais',
#   'Cês, êsses, recortes curvos, frisos, molduras e almofadas, pilastras com capitéis; pintura em motivos florais; Representação dos símbolos da Paixão, as “Armas Christi”, como são conhecidos o conjunto de instrumentos utilizados e relacionados com a Paixão de Cristo, como a escada, a lança que trespassou seu peito, a esponja, a corda, a coroa de espinhos, o cálice que recolheu seu sangue; o chicote, a tabuleta com a inscrição “INRI” pregada no alto da cruz e os três cravos da crucificação. A representação desses símbolos na arte cristã esta relacionada a um sonho que teve S. Gregório Magno (eleito papa em 590), em que Jesus Cristo descia do céu no momento da missa e mostrava aos fiéis seus estigmas e os instrumentos de sua Paixão.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto. No Cuiabá, hoje distrito Mestre Caetano, existem duas capelas antigas: a de Nossa Senhora do Rosário, cuja decoração retabular é típica da 1a fase do barroco em Minas Gerais (o estilo Nacional Português) evoluída para a 2a (estilo Joanino), portanto, datando do 2o quartel do século XVIII; a de Santa Ifigênia, despojada de decoração, mas cuja arquitetura remete ás construções do século XVIII.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 26-03-1975; Ficha de Conservação e Restauração 22-10-1990; Ficha Topográfica 1991-1997. HEINZ-MOHR, Gerd. Dicionário dos Símbolos. Imagens e sinais da arte cristã. São Paulo, Paulus, 1994. PASTOUREAU, Michel. La Biblia y los Santos. Madrid, Alianza Editorial, 1996.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '418'],
#  ['Denominação', 'Oratório'],
#  ['Outros números', 'MO 418 | Tombo nº 1950.02.07'],
#  ['Classificação', '05 Interiores > 05.5 Peça de Mobiliário'],
#  ['Local de produção', 'Brasil | Minas Gerais'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'Santa Bárbara'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'dourada | madeira entalhada | policromada | recortada'],
#  ['Palavras-chave',
#   'minas gerais | mobiliário | religião | rococó | século xviii'],
#  ['Fotógrafo', 'Daniel Mansur'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Tipo de tombamento', 'Tombamento em conjunto'],
#  ['Dimensões',
#   'Altura (cm): 106,0 Largura (cm): 49,0 Comprimento (cm): Profundidade (cm): 22,0 Diâmetro (cm): Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Oratório retangular, de base emoldurada, com registro inferior em uma gaveta emoldurada, pintada de vermelho, com laterais brancas; com moldura vermelha e branco acima; parte central com porta de duas bandas, de recorte arqueado superior; cada banda com três almofadas reentrantes, com retângulo central em vermelho e azul, frisado de dourado; batente emoldurada e frisada de dourado; contorno em frisos dourados e montantes brancos, com as quinas emolduradas e frisadas em dourado; abas laterais recortadas em curvas, delimitadas por angras, cês, esses, volutas e acantos em dourado, com o interior branco; arremate superior em cimalha azul com frisos dourados, encimada por uma palmeta vermelha, com lingüeta dourada ao meio e contorno em cês, volutas e frisos dourados; laterais marmorizadas em vermelho e amarelo; faces internas da porta, com pintura de compoteira vermelha, de alças curvas, com arranjo de flores vermelhas e ramos verdes; moldura interna em recortes curvos e vazados com angras, êsses e cês dourados; com a parte superior em três cês dourados, com palmeta central e molduras irregulares nos cantos, contornadas por friso dourado e de fundo vermelho; fundo, laterais e forro do oratório, com pintura em motivos florais vermelhos com ramos verdes, delimitada por ramicelos e estrias verdes, sobre fundo azul. Atualmente tem em seu interior a imagem de São José de Botas (no 417).'],
#  ['Características técnicas',
#   'Oratório em cedro, composto de várias partes entalhadas, recortadas, encaixadas e fixadas por cravos; policromia em vermelho, branco, amarelo, azul e verde; douramento; porta com quatro dobradiças de ferro batido, fechadas por duas tramelas.'],
#  ['Características estilísticas',
#   'Oratório de origem mineira, de composição elaborada, em linhas sinuosas, com decoração de gosto rococó, em angras, cês, êsses, lingüetas e palmetas D. José; a pintura, em motivos florais, encontra-se um pouco danificada pelas repinturas posteriores; datável do último quartel do século XVIII.'],
#  ['Características iconográficas/ornamentais',
#   'Cês, angras, êsses, palmetas D. José, lingüetas, concheados, volutas, acantos, frisos dourados e molduras; pintura em motivos florais, com rosas e ramos; compoteira.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 26-03-1975; Ficha de Conservação e Restauração de 22-10-1990; Ficha Topográfica 1991-1996.'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '410'],
#  ['Denominação', 'Escultura Religiosa'],
#  ['Título', 'São Miguel'],
#  ['Outros números', 'MO 410 | Tombo nº 1950.02.02'],
#  ['Classificação', '02 Artes Visuais/Cinematográfica > 02.3 Escultura'],
#  ['Local de produção', '[Minas Gerais]'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'Desconhecida'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'dourada | madeira esculpida | policromada'],
#  ['Palavras-chave', 'escola mineira | escultura | religião | século xviii'],
#  ['Fotógrafo', 'Daniel Mansur'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Tipo de tombamento', 'Tombamento em conjunto'],
#  ['Dimensões',
#   'Altura (cm): 83,0 Largura (cm): 40,0 Comprimento (cm): Profundidade (cm): 23,0 Diâmetro (cm): Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Figura masculina, jovem, de pé, em posição frontal; cabeça ligeiramente inclinada à frente; olhos abaixados; cabelos em mechas grossas com as pontas em volutas; braço direito erguido, com a mão de segurar; braço esquerdo estendido para o lado, abaixado, com a mão no gesto típico de segurar a balança; pernas retas, com os pés quase em paralelo, estando o esquerdo com o calcanhar suspenso. Vestido com armadura de gola em “V”, com recortes semicirculares, dourados; ao centro relevo de flor quadripartida, rodeada por frisos dourados e botões esféricos; na barra, elemento fitomorfo; saiote de pregas sobrepostas, em verde com detalhes dourados, terminados em franjas vermelhos; calçado com botas de cano alto, verdes, com dobras vermelhas com firmal à altura dos joelhos; manto vermelho jogado para trás, enrolado no ombro direito; usa luvas verdes, com dobras douradas nos punhos; sobre a cabeça, um capacete com tapa-orelhas, arrematado por penacho, com decoração em volutas, frisos, botões esféricos, em verde com detalhes dourados; par de asas retas, alongadas, com desenho das penas em relevo. Base atributiva, com tufos de nuvens esverdeadas e a parte inferior retangular, emoldurada.'],
#  ['Características técnicas',
#   'Peça em madeira esculpida, composta por várias pequenas partes encaixadas e pregadas; dourada e policromada nas cores verde, vermelho, bege e preto; base com pino de ferro.'],
#  ['Características estilísticas',
#   'Imagem de provável origem mineira, datável do século XVIII ou XIX, de cunho bem popular, com rosto inexpressivo, composição sem movimento, com panejamento em pregas duras e confusas, principalmente na disposição do manto; asas bem retas; os cabelos, terminados em volutas, lembram as imagens de fins do século XVII e início do XVIII.'],
#  ['Características iconográficas/ornamentais',
#   'São Miguel tem seu culto muito difundido em Minas Gerais. Sua devoção, no período colonial, vinculou-se às irmandades para o resgate das Almas do Purgatório, daí o nome São Miguel e Almas, tão comum em Minas Gerais. A sua representação insere-se dentro de uma tradição hagiográfica que resulta na formula de mesclar duas cenas em uma só: a pesagem das almas e a peleja contra o demônio; na primeira, a pesagem das almas, S. Miguel traz uma balança, em cujos pratos pode se vê, às vezes, pequenas alminhas esculpidas; na outra cena, alusiva a uma passagem do Apocalipse (12: 7-8), é o São Miguel guerreiro, empunhando uma espada ou lança investida contra o demônio que aparece sob seus pés (aqui não tem), e que a imaginação dos artistas emprestou as mais fantasiosas feições.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 26-03-1975; Ficha de Conservação e Restauração de 08-02-1990; Ficha Topográfica 1991-1998. JUSTINIANO, Fátima A. de S. Restauração de uma escultura policromada. São Miguel Arcanjo. Belo Horizonte, CECOR, 1990. MEGALE, Nilza Botelho. Santos do Povo Brasileiro. Petropólis/RJ, Vozes, 2002 PASTOREAU, Michel. La Biblia y los Santos. Madrid, Alianza Editorial, 1996. ROIG, Juan Ferrando. Iconografía de los Santos. Barcelona, Ediciones Omega, 1950'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '409'],
#  ['Denominação', 'Escultura Religiosa'],
#  ['Título', 'Santo André'],
#  ['Outros números', 'MO 409 | Tombo nº 1950.02.01'],
#  ['Classificação', '02 Artes Visuais/Cinematográfica > 02.3 Escultura'],
#  ['Local de produção', '[Minas Gerais]'],
#  ['Data de produção', 'Século XVIII'],
#  ['Procedência', 'Sabará'],
#  ['Autor', 'Não identificado'],
#  ['Material/Técnica', 'dourada | madeira esculpida | policromada'],
#  ['Palavras-chave', 'escola mineira | escultura | religião | século xviii'],
#  ['Fotógrafo', 'Daniel Mansur'],
#  ['Data da fotografia', '2007'],
#  ['Esfera de proteção legal', 'Federal'],
#  ['Tipo de tombamento', 'Tombamento em conjunto'],
#  ['Dimensões',
#   'Altura (cm): 60,0 Largura (cm): 33,5 Comprimento (cm): Profundidade (cm): 15,5 Diâmetro (cm): Peso (g): Circunferência (cm):'],
#  ['Resumo descritivo',
#   'Figura masculina, meia-idade, de pé, em posição frontal, cabeça inclinada à esquerda; calvo no alto do crânio, com cabelos caídos por trás em mechas sinuosas e estriadas; e um topete na frente, em mechas onduladas; barba longa, em mechas onduladas, com furo abaixo do queixo; bigode saindo das narinas; braço direito flexionado para o lado, mão segurando um travessão da cruz que tem por trás; braço esquerdo flexionado lateralmente, mão segurando um livro fechado, que é pressionado junto ao corpo; livro de capa bege, com fechos; perna esquerda flexionada e a direita reta; pés posicionados à direita. Vestido de túnica longa, vermelha, cingida na cintura, com padronagem em dourado; capa ocre, envolvendo os ombros e enrolada na parte central do corpo, com resquícios de padronagem fitomorfa; calçado com sapatos marrons. Tem por trás uma cruz em “X”, com travessões imitando tronco desgalhado de árvore, em tons marrons. Base de formato quadrado, irregular, com chanfros na face esquerda; marmorizada em azul, branco e preto.'],
#  ['Características técnicas',
#   'Peça esculpida em três partes de madeira, com encaixes nos travessões da cruz; dourada e policromada em vermelho, ocre, bege, marrom, azul, branco e verde.'],
#  ['Características estilísticas',
#   'Imagem datável do século XVIII, 2ª metade, de composição erudita, panejamento farto e movimentado; rosto expressivo, de cabelos e barba em mechas onduladas e estriadas, olhos com recortes alongados, pálpebras bem demarcadas, boca de lábios pequenos, recortados, orelhas planas e mãos com dedos finos. De provável origem mineira.'],
#  ['Características iconográficas/ornamentais',
#   'A imagem de Santo André bem como o seu culto não são muito comuns em Minas Gerais. Bem poucas são as imagens conhecidas, em igrejas mineiras do período colonial, relativas a essa representação. Santo André, como um dos primeiros discípulos de Jesus, juntamente com seu irmão Pedro, é geralmente representado vestido com uma túnica e manto largos, indumentária comum aos apóstolos; como atributo pessoal tema cruz em “X”, conhecida como Cruz de Santo André, e que faz alusão ao seu instrumento de martírio; o livro que traz na mão é também um atributo comum aos apóstolos.'],
#  ['Dados históricos',
#   'Não foram localizados dados específicos sobre o objeto.'],
#  ['Referências bibliográficas/arquivísticas',
#   'Ficha Cadastral de 26-03-1975; Ficha de Conservação e Restauração 08-02-1990; Ficha Topográfica 1991-1997. 1 foto P&B no 241 e 6 fotos coloridas grandes. ROIG, Juan Ferrando. Iconografia de los Santos. Barcelona, Ediciones Omega, 1950'],
#  ['Condições de reprodução',
#   'Domínio público, ver http://museudoouro.acervos.museus.gov.br/reproducao-de-imagens-do-acervo/'],
#  ['Número de registro', '401'],
#  ['Denominação', 'Moringa (bilha)'],
#  ['Outros números', 'MO 401 | Tombo nº 1950.16.01'],
#  ['Classificação', '05 Interiores > 05.6 Utensílio de Cozinha/Mesa'],
#  ...]

# %%
#Cria o dataframe
df = pd.DataFrame(rows,columns=["metadado","valor"])

#Salva o dataframe em csv . Usei separacao por ; para melhor visualizar o arquivo csv no excel
df.to_csv("base_out3.csv",index=False,sep=';',encoding='utf-16')
